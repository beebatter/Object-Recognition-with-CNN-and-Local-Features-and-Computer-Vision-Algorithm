# %%
import cv2

from sklearn.cluster import MiniBatchKMeans
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import pickle

print("all libraries loaded successfully.")
print(f"OpenCV version: {cv2.__version__}")
# Out:
# all libraries loaded successfully.
# OpenCV version: 4.11.0

# %%
# --- config ----
from enum import Enum
import os
import cv2
import numpy as np
from typing import List, Tuple, Dict, Optional
from sklearn.model_selection import train_test_split

class Config:
    """Configuration class"""
    DATA_DIR = "Dataset/iCubWorld1/" # Dataset directory
    IMAGE_SIZE = (256, 256)     # image size
    VOCAB_SIZE = 400 # visual vocabulary size(K value)
    RANDOM_STATE = 42 # random state for reproducibility
    IMAGE_EXT = '.ppm' # image extension
    MAX_CORNERS = 200 # Harris
    HARRIS_MIN_DISTANCE = 4 # Harris
    HARRIS_QUALITY_LEVEL = 0.01 # Harris
    HARRIS_THRESH = 1e-4     # Harris
    DETECTOR_TYPE = 'HARRIS_SIFT'  #  SIFT，‘ORB’，‘HARRIS_SIFT’，‘HARRIS_AFFINE’
    FEATURE_LIMIT_PER_IMAGE = 100 #
    VOCAB_SAMPLE_LIMIT = 6000 #

    # Harris parameters
    AFFINE_MAX_ITERATIONS = 20
    AFFINE_RESPONSE_THRESHOLD = 0.01
    AFFINE_EDGE_THRESHOLD = 10
    INIT_KEYPOINT_SIZE = 20

class BaseDataLoader:
    """basedata loader"""
    def __init__(self, data_dir: str = Config.DATA_DIR):
        self.data_dir = data_dir
        # check the dir
        if not os.path.exists(self.data_dir):
             raise FileNotFoundError(f"don't find the dir: {self.data_dir}")
        train_dir = os.path.join(self.data_dir, "train")
        if not os.path.exists(train_dir):
             raise FileNotFoundError(f"Train dir didn't find: {train_dir}")
        self.classes = self._load_classes()

    def _load_classes(self) -> List[str]:
        train_dir = os.path.join(self.data_dir, "train")
        classes = []
        for name in os.listdir(train_dir):
            full = os.path.join(train_dir, name)
            if os.path.isdir(full):
                classes.append(name)
        return sorted(classes)

    def _collect_images(self, directory: str, is_test: bool = False) -> Tuple[List[str], List[int]]:
        paths, labels = [], []
        if not os.path.exists(directory):
            print(f"Warn: directory didn't exist: {directory}")
            return paths, labels

        class_name = ""
        if is_test:
            # `testset：test/modes/bananas/000000.ppm
             parts = directory.split(os.sep)
             if len(parts) >= 2:
                 class_name = parts[-1]
             else:
                 print(f"Warn: can't sure the categories name: {directory}")
                 return paths, labels

        else:
            # Trainset：train/bananas/bananas_1/000000.ppm

            parts = directory.split(os.sep)
            if len(parts) >= 2:
                 class_name = parts[-2]
            else:
                 print(f"Warn: can't sure the categories name{directory}")
                 return paths, labels


        try:
            class_idx = self.classes.index(class_name)
        except ValueError:

            print(f"Warn: Unknow class '{class_name}' in dir: {directory}")

            return paths, labels

        for fname in os.listdir(directory):
            if fname.endswith(Config.IMAGE_EXT):
                paths.append(os.path.join(directory, fname))
                labels.append(class_idx)

        return paths, labels

    def get_class_names(self) -> List[str]:
        return self.classes

class TrainDataLoader(BaseDataLoader):
    def __init__(self, data_dir: str = Config.DATA_DIR, max_samples_per_class: Optional[int] = None):
        super().__init__(data_dir)
        self.max_samples_per_class = max_samples_per_class

    def load_data(self) -> Tuple[List[str], List[int]]:
        all_paths, all_labels = [], []
        train_root = os.path.join(self.data_dir, "train")

        print("Start load the train data...")
        for idx, cls in enumerate(tqdm(self.classes, desc="categories")):
            cls_dir = os.path.join(train_root, cls)
            class_paths_collected = []
            class_labels_collected = []

            for instance in os.listdir(cls_dir):
                instance_dir = os.path.join(cls_dir, instance)
                if os.path.isdir(instance_dir):
                    paths, labels = self._collect_images(instance_dir, is_test=False)
                    class_paths_collected.extend(paths)
                    class_labels_collected.extend(labels)

            if self.max_samples_per_class is not None and len(class_paths_collected) > self.max_samples_per_class:
                indices = np.random.choice(len(class_paths_collected), self.max_samples_per_class, replace=False)
                sampled_paths = [class_paths_collected[i] for i in indices]
                sampled_labels = [class_labels_collected[i] for i in indices]
                all_paths.extend(sampled_paths)
                all_labels.extend(sampled_labels)
            else:
                all_paths.extend(class_paths_collected)
                all_labels.extend(class_labels_collected)

        print(f"Finished the load.... Total {len(all_paths)} images。")
        return all_paths, all_labels


class TestDataLoader(BaseDataLoader):
    """Load the test data"""
    def __init__(self, data_dir: str = Config.DATA_DIR, max_samples_per_class: Optional[int] = None):
        super().__init__(data_dir)
        self.max_samples_per_class = max_samples_per_class
        test_dir = os.path.join(data_dir, "test")
        if not os.path.exists(test_dir):
            raise ValueError(f"Test dir do not exist: {test_dir}")

        self.test_types = [d for d in os.listdir(test_dir) if os.path.isdir(os.path.join(test_dir, d))]
        if not self.test_types:
             print(f"Warn: Can't find the sub dir under {test_dir} ")
        else:
            print(f"find the test type: {self.test_types}")


    def load_data(self) -> Dict[str, Tuple[List[str], List[int]]]:
        """加载测试数据"""
        test_sets = {}
        test_root = os.path.join(self.data_dir, "test")

        print("Start load the test data...")
        for test_type in tqdm(self.test_types, desc="categories"):
            try:
                paths, labels = self._load_test_type(test_type)
                if paths:
                    test_sets[test_type] = (paths, labels)
                    self._print_test_set_stats(test_type, paths, labels)
                    if len(paths) != len(labels):
                         raise ValueError(f"path and labels do not match: {len(paths)} vs {len(labels)}")
                else:
                    print(f"Warn: Test type {test_type} didn't load any data")

            except Exception as e:
                print(f"erro in load {test_type} : {str(e)}")
                test_sets[test_type] = ([], [])

        print("Finished the loading of data")
        return test_sets

    def _load_test_type(self, test_type: str) -> Tuple[List[str], List[int]]:
        paths, labels = [], []
        test_type_dir = os.path.join(self.data_dir, "test", test_type)

        for cls in self.classes:
            cls_dir = os.path.join(test_type_dir, cls)

            if not os.path.exists(cls_dir):
                continue

            cls_paths, cls_labels = self._collect_images(cls_dir, is_test=True)

            if cls_paths:
                if self.max_samples_per_class is not None:
                    cls_paths, cls_labels = self._sample_data(cls_paths, cls_labels)

                paths.extend(cls_paths)
                labels.extend(cls_labels)

        return paths, labels

    def _sample_data(self, paths: List[str], labels: List[int]) -> Tuple[List[str], List[int]]:
        sample_size = min(len(paths), self.max_samples_per_class)
        if sample_size == 0:
             return [], []
        indices = np.random.choice(len(paths), sample_size, replace=False)
        return [paths[i] for i in indices], [labels[i] for i in indices]

    def _print_test_set_stats(self, test_type: str, paths: List[str], labels: List[int]) -> None:
        """print"""
        if not paths:
            return
        print(f"\n--- Testset: {test_type} ---")
        print(f"Total sample: {len(paths)}")


        unique_labels, counts = np.unique(labels, return_counts=True)
        label_counts = dict(zip(unique_labels, counts))

        for idx, cls in enumerate(self.classes):
            count = label_counts.get(idx, 0)
            percentage = (count / len(labels) * 100) if labels else 0
            print(f"  categories {cls}: {count} sample ({percentage:.1f}%)")
        print("-" * (len(f"--- testset: {test_type} ---")))

print("Finished the load of testloader")
# Out:
# Finished the load of testloader

# %%
from tqdm import tqdm

# random seed
np.random.seed(Config.RANDOM_STATE)


train_loader = TrainDataLoader(data_dir=Config.DATA_DIR)
test_loader = TestDataLoader(data_dir=Config.DATA_DIR)

# load the data
train_paths, train_labels = train_loader.load_data()
test_sets = test_loader.load_data()

class_names = train_loader.get_class_names()

print(f"\n loded the data: ")
print(f" - Training smaples: {len(train_paths)}")
print(f" - Number of class: {len(class_names)}")
print(f" - class name: {class_names}")
print(f" - test mode: {list(test_sets.keys())}")

# 检查是否有测试数据被加载
if not test_sets:
    print("\n warning: there is no test data loaded, please check the TestDataLoader logic and test data directory structure.")
else:
    for test_type, (paths, _) in test_sets.items():
        print(f" - Testset '{test_type}' sample: {len(paths)}")


if train_paths:
    img_example = cv2.imread(train_paths[0])
    if img_example is not None:
        plt.imshow(cv2.cvtColor(img_example, cv2.COLOR_BGR2RGB))
        plt.title(f"sample image: {class_names[train_labels[0]]}")
        plt.axis('off')
        plt.show()
    else:
        print(f"Can't load the image: {train_paths[0]}")
else:
    print("there is no training data loaded, please check the TrainDataLoader logic and test data directory structure.")
# Out:
# find the test type: ['background', 'categorization', 'demonstrator', 'robot']
# Start load the train data...
# categories: 100%|██████████| 10/10 [00:00<00:00, 205.10it/s]
# Finished the load.... Total 6002 images。
# Start load the test data...
# categories:   0%|          | 0/4 [00:00<?, ?it/s]
# --- Testset: background ---
# Total sample: 100
#   categories bananas: 10 sample (10.0%)
#   categories bottles: 10 sample (10.0%)
#   categories boxes: 10 sample (10.0%)
#   categories bread: 10 sample (10.0%)
#   categories cans: 10 sample (10.0%)
#   categories lemons: 10 sample (10.0%)
#   categories pears: 10 sample (10.0%)
#   categories peppers: 10 sample (10.0%)
#   categories potatoes: 10 sample (10.0%)
#   categories yogurt: 10 sample (10.0%)
# ---------------------------
#
# --- Testset: categorization ---
# Total sample: 2001
#   categories bananas: 200 sample (10.0%)
#   categories bottles: 200 sample (10.0%)
#   categories boxes: 200 sample (10.0%)
#   categories bread: 200 sample (10.0%)
#   categories cans: 200 sample (10.0%)
#   categories lemons: 200 sample (10.0%)
#   categories pears: 200 sample (10.0%)
#   categories peppers: 200 sample (10.0%)
#   categories potatoes: 200 sample (10.0%)
#   categories yogurt: 201 sample (10.0%)
# -------------------------------
# categories: 100%|██████████| 4/4 [00:00<00:00, 85.62it/s]
# --- Testset: demonstrator ---
# Total sample: 2001
#   categories bananas: 200 sample (10.0%)
#   categories bottles: 200 sample (10.0%)
#   categories boxes: 200 sample (10.0%)
#   categories bread: 200 sample (10.0%)
#   categories cans: 200 sample (10.0%)
#   categories lemons: 200 sample (10.0%)
#   categories pears: 201 sample (10.0%)
#   categories peppers: 200 sample (10.0%)
#   categories potatoes: 200 sample (10.0%)
#   categories yogurt: 200 sample (10.0%)
# -----------------------------
#
# --- Testset: robot ---
# Total sample: 802
#   categories bananas: 64 sample (8.0%)
#   categories bottles: 76 sample (9.5%)
#   categories boxes: 76 sample (9.5%)
#   categories bread: 83 sample (10.3%)
#   categories cans: 75 sample (9.4%)
#   categories lemons: 83 sample (10.3%)
#   categories pears: 76 sample (9.5%)
#   categories peppers: 69 sample (8.6%)
#   categories potatoes: 70 sample (8.7%)
#   categories yogurt: 130 sample (16.2%)
# ----------------------
# Finished the loading of data
#
#  loded the data:
#  - Training smaples: 6002
#  - Number of class: 10
#  - class name: ['bananas', 'bottles', 'boxes', 'bread', 'cans', 'lemons', 'pears', 'peppers', 'potatoes', 'yogurt']
#  - test mode: ['background', 'categorization', 'demonstrator', 'robot']
#  - Testset 'background' sample: 100
#  - Testset 'categorization' sample: 2001
#  - Testset 'demonstrator' sample: 2001
#  - Testset 'robot' sample: 802

# %%
def extract_sift_features(image_path: str, feature_limit: Optional[int] = None) -> Optional[np.ndarray]:

    try:
        img = cv2.imread(image_path)
        if img is None:
            print(f"Warning: can't load image: {image_path}")
            return None 

        if len(img.shape) == 2 or (len(img.shape) == 3 and img.shape[2] == 1):
            gray = img
        elif len(img.shape) == 3 and img.shape[2] == 3:
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        elif len(img.shape) == 3 and img.shape[2] == 4:
            gray = cv2.cvtColor(img, cv2.COLOR_BGRA2GRAY)
        else:
            print(f"Warning: Image {image_path}can not identify the path: {img.shape}. Skip this image。")
            return None 


        sift = cv2.SIFT_create()

        keypoints = []
        descriptors = None

        if Config.DETECTOR_TYPE == 'SIFT':
            sift = cv2.SIFT_create(nfeatures=getattr(Config, 'FEATURE_LIMIT_PER_IMAGE', 0))
            keypoints, descriptors = sift.detectAndCompute(gray, None)

        elif Config.DETECTOR_TYPE == 'ORB':
            orb = cv2.ORB_create(nfeatures=getattr(Config, 'FEATURE_LIMIT_PER_IMAGE', 500))
            keypoints, descriptors = orb.detectAndCompute(gray, None)

        elif Config.DETECTOR_TYPE == 'HARRIS_SIFT':
            
            corners = cv2.goodFeaturesToTrack(
                gray,
                maxCorners=Config.MAX_CORNERS,
                qualityLevel=Config.HARRIS_QUALITY_LEVEL,
                minDistance=Config.HARRIS_MIN_DISTANCE,
            )

            if corners is not None and len(corners) > 0:
                keypoints = [
                    cv2.KeyPoint(
                        float(pt[0][0]),  # x
                        float(pt[0][1]),  # y
                        20                # size
                    )
                    for pt in corners
                ] 


                sift_descriptor_extractor = cv2.SIFT_create()

                keypoints, descriptors = sift_descriptor_extractor.compute(gray, keypoints)

            else:
                keypoints = []
                descriptors = np.array([]) 

        elif Config.DETECTOR_TYPE == 'HARRIS_AFFINE':
                corners = cv2.goodFeaturesToTrack(
                    gray,
                    maxCorners=Config.MAX_CORNERS,
                    qualityLevel=Config.HARRIS_QUALITY_LEVEL,
                    minDistance=Config.HARRIS_MIN_DISTANCE
                )
                if corners is None or len(corners) == 0:
                    return None

                init_kps = [
                    cv2.KeyPoint(float(c[0][0]), float(c[0][1]), Config.INIT_KEYPOINT_SIZE)
                    for c in corners
                ]

                sift_base = cv2.xfeatures2d.SIFT_create()
                affine_detector = cv2.xfeatures2d.AffineAdaptedFeatureDetector_create(
                    sift_base,
                    maxIterations=Config.AFFINE_MAX_ITERATIONS,
                    responseThreshold=Config.AFFINE_RESPONSE_THRESHOLD,
                    edgeThreshold=Config.AFFINE_EDGE_THRESHOLD
                )

                affine_kps = affine_detector.detect(gray, init_kps)

                keypoints, descriptors = sift_base.compute(gray, affine_kps)

        else:
            raise ValueError(f"Unknown DETECTOR_TYPE: {Config.DETECTOR_TYPE}")

            keypoints, descriptors = sift.detectAndCompute(img, None)



            if descriptors is None or len(descriptors) == 0:
                print(f"`info: Can't find SIFT descriptors in image {os.path.basename(image_path)} .")
                return None

            if feature_limit is not None and len(keypoints) > feature_limit:
                indices = np.argsort([kp.response for kp in keypoints])[::-1][:feature_limit]
                descriptors = descriptors[indices]
                # keypoints = [keypoints[i] for i in indices] 

        return descriptors.astype(np.float32) 

    except Exception as e:
        print(f"Error: Wrong when process the image {image_path} : {e}")
        return None

if train_paths:
    print("extracting features from the first training image...")
    example_descriptors = extract_sift_features(train_paths[0], feature_limit=Config.FEATURE_LIMIT_PER_IMAGE)
    if example_descriptors is not None:
        print(f"sample image extract  {example_descriptors[0]} descriptors, then the dimension is {example_descriptors.shape[1]}")
    else:
        print("fail to extract the features, please check the image path and the image format.")
else:
    print("no training data, skip the feature extraction test.")
# Out:
# extracting features from the first training image...
# sample image extract  [  3.  12.  83.   4.   2.   4.  37.   6.   6.  11.  70.  23.  14.   9.
#   46.   7.   3.   3.  12.   7.   7.   4.   8.   2.   0.   0.   0.   0.
#    0.   0.   0.   0.  19.  24.  78.  10.  33.  64. 135.  34.  29.  24.
#   81.  38.  52.  63. 135.  61.   6.   3.   7.  18.  31.  26.  19.   7.
#    0.   0.   0.   0.   0.   0.   0.   0.  36.  57. 135.  24.  20.  72.
#  135.  59.   8.  23. 135.  86.  58.  58. 135.  64.   1.   3.  21.  38.
#   31.  23.  59.   4.   0.   0.   0.   0.   0.   0.   0.   0.   5.  28.
#  135.  28.   4.  13.  64.  19.   1.   8. 135.  83.   3.   6.  85.  19.
#    0.   3.  40.  20.   1.   3.  17.   1.   0.   0.   0.   0.   0.   0.
#    0.   0.] descriptors, then the dimension is 128

# %%
# --- Visual Vocabulary Construction---

def build_vocabulary(image_paths: List[str], vocab_size: int, sample_limit: Optional[int] = None) -> Optional[
    MiniBatchKMeans]:
    all_descriptors = []
    print(f"Start extracting features to build vocabulary...")

    paths_to_process = image_paths
    if sample_limit is not None and len(image_paths) > sample_limit:
        print(f"Randomly sampling {sample_limit} images from {len(image_paths)} images to build vocabulary...")
        paths_to_process = np.random.choice(image_paths, sample_limit, replace=False).tolist()

    for image_path in tqdm(paths_to_process, desc="Extracting vocabulary features"):
        descriptors = extract_sift_features(image_path, feature_limit=Config.FEATURE_LIMIT_PER_IMAGE)
        if descriptors is not None:
            all_descriptors.append(descriptors)

    if not all_descriptors:
        print("Error: Could not extract features from any images to build vocabulary.")
        return None

    stacked_descriptors = np.vstack(all_descriptors)
    print(f"Extracted {stacked_descriptors.shape[0]} descriptors to build vocabulary.")

    if stacked_descriptors.shape[0] < vocab_size:
        print(
            f"Warning: Number of descriptors ({stacked_descriptors.shape[0]}) is less than vocabulary size ({vocab_size}). Reducing vocabulary size to {stacked_descriptors.shape[0]}.")
        vocab_size = stacked_descriptors.shape[0]
        if vocab_size == 0:
            print("Error: Number of descriptors is 0, cannot perform clustering.")
            return None

    print(f"Starting MiniBatchKMeans to build visual vocabulary of size {vocab_size}...")
    kmeans = MiniBatchKMeans(n_clusters=vocab_size,
                             random_state=Config.RANDOM_STATE,
                             batch_size=256 * 8,  # adjustable parameter
                             init='k-means++',  # initialization method
                             max_iter=100,  # adjustable parameter
                             n_init=10,  # explicitly set n_init
                             verbose=1)  # can set to 1 to see progress

    kmeans.fit(stacked_descriptors)
    print("Visual vocabulary construction complete.")

    return kmeans


vocabulary_kmeans = build_vocabulary(train_paths, Config.VOCAB_SIZE, sample_limit=Config.VOCAB_SAMPLE_LIMIT)

if vocabulary_kmeans:
    vocab_filename = f"visual_vocabulary_k{Config.VOCAB_SIZE}.pkl"
    with open(vocab_filename, 'wb') as f:
        pickle.dump(vocabulary_kmeans, f)
    print(f"Visual vocabulary saved to {vocab_filename}")
else:
    print("Failed to build visual vocabulary. Following steps cannot proceed.")
# Out:
# Start extracting features to build vocabulary...
# Randomly sampling 6000 images from 6002 images to build vocabulary...
# Extracting vocabulary features: 100%|██████████| 6000/6000 [00:58<00:00, 103.20it/s]
# Extracted 1169755 descriptors to build vocabulary.
# Starting MiniBatchKMeans to build visual vocabulary of size 400...
# Init 1/10 with method k-means++
# Inertia for init 1/10: 417170912.0
# Init 2/10 with method k-means++
# Inertia for init 2/10: 419466496.0
# Init 3/10 with method k-means++
# Inertia for init 3/10: 415142016.0
# Init 4/10 with method k-means++
# Inertia for init 4/10: 414568256.0
# Init 5/10 with method k-means++
# Inertia for init 5/10: 415960640.0
# Init 6/10 with method k-means++
# Inertia for init 6/10: 417314464.0
# Init 7/10 with method k-means++
# Inertia for init 7/10: 415612416.0
# Init 8/10 with method k-means++
# Inertia for init 8/10: 419536896.0
# Init 9/10 with method k-means++
# Inertia for init 9/10: 417103232.0
# Init 10/10 with method k-means++
# Inertia for init 10/10: 417958976.0
# [MiniBatchKMeans] Reassigning 21 cluster centers.
# Minibatch step 1/57116: mean batch inertia: 67036.25
# Minibatch step 2/57116: mean batch inertia: 54653.0234375, ewa inertia: 54653.0234375
# Minibatch step 3/57116: mean batch inertia: 51690.03515625, ewa inertia: 54642.64828233943
# Minibatch step 4/57116: mean batch inertia: 50840.4609375, ewa inertia: 54629.33460037117
# Minibatch step 5/57116: mean batch inertia: 50182.50390625, ewa inertia: 54613.76364495558
# Minibatch step 6/57116: mean batch inertia: 49793.4140625, ewa inertia: 54596.884781423585
# [MiniBatchKMeans] Reassigning 8 cluster centers.
# Minibatch step 7/57116: mean batch inertia: 48469.01953125, ewa inertia: 54575.427540712946
# Minibatch step 8/57116: mean batch inertia: 49513.3828125, ewa inertia: 54557.702361097065
# Minibatch step 9/57116: mean batch inertia: 47890.1484375, ewa inertia: 54534.355354652085
# Minibatch step 10/57116: mean batch inertia: 48990.93359375, ewa inertia: 54514.944592465225
# Minibatch step 11/57116: mean batch inertia: 48696.3984375, ewa inertia: 54494.57045884185
# Minibatch step 12/57116: mean batch inertia: 47736.26953125, ewa inertia: 54470.90569405379
# Minibatch step 13/57116: mean batch inertia: 48232.13671875, ewa inertia: 54449.06011452879
# Minibatch step 14/57116: mean batch inertia: 48013.9609375, ewa inertia: 54426.527068125
# Minibatch step 15/57116: mean batch inertia: 48473.5078125, ewa inertia: 54405.682065516725
# Minibatch step 16/57116: mean batch inertia: 47754.95703125, ewa inertia: 54382.393986857285
# [MiniBatchKMeans] Reassigning 2 cluster centers.
# Minibatch step 17/57116: mean batch inertia: 48083.1171875, ewa inertia: 54360.336534046466
# Minibatch step 18/57116: mean batch inertia: 48606.30078125, ewa inertia: 54340.188289076184
# Minibatch step 19/57116: mean batch inertia: 47661.65625, ewa inertia: 54316.80284182731
# Minibatch step 20/57116: mean batch inertia: 47212.15234375, ewa inertia: 54291.925304597215
# Minibatch step 21/57116: mean batch inertia: 47090.484375, ewa inertia: 54266.708847449205
# Minibatch step 22/57116: mean batch inertia: 47378.97265625, ewa inertia: 54242.59085409063
# Minibatch step 23/57116: mean batch inertia: 47248.578125, ewa inertia: 54218.100724406875
# Minibatch step 24/57116: mean batch inertia: 47550.859375, ewa inertia: 54194.75481246697
# Minibatch step 25/57116: mean batch inertia: 46907.5078125, ewa inertia: 54169.23789807469
# Minibatch step 26/57116: mean batch inertia: 47989.4765625, ewa inertia: 54147.598938812655
# Minibatch step 27/57116: mean batch inertia: 47859.3515625, ewa inertia: 54125.58010646353
# Minibatch step 28/57116: mean batch inertia: 48012.6875, ewa inertia: 54104.17529373671
# Minibatch step 29/57116: mean batch inertia: 46688.234375, ewa inertia: 54078.20774665583
# Minibatch step 30/57116: mean batch inertia: 47068.6328125, ewa inertia: 54053.66312458909
# Minibatch step 31/57116: mean batch inertia: 47568.28515625, ewa inertia: 54030.954022726546
# Minibatch step 32/57116: mean batch inertia: 46923.50390625, ewa inertia: 54006.06668239481
# Minibatch step 33/57116: mean batch inertia: 47574.9609375, ewa inertia: 53983.547619332865
# Minibatch step 34/57116: mean batch inertia: 47564.6796875, ewa inertia: 53961.07140801291
# Minibatch step 35/57116: mean batch inertia: 46470.8515625, ewa inertia: 53934.84376696023
# Minibatch step 36/57116: mean batch inertia: 47103.0859375, ewa inertia: 53910.921786590414
# Minibatch step 37/57116: mean batch inertia: 46007.30078125, ewa inertia: 53883.246586259855
# Minibatch step 38/57116: mean batch inertia: 46350.41015625, ewa inertia: 53856.86971961645
# Minibatch step 39/57116: mean batch inertia: 46864.421875, ewa inertia: 53832.38506950861
# Minibatch step 40/57116: mean batch inertia: 46238.7734375, ewa inertia: 53805.7953933328
# Minibatch step 41/57116: mean batch inertia: 46600.984375, ewa inertia: 53780.56713553281
# Minibatch step 42/57116: mean batch inertia: 46425.6796875, ewa inertia: 53754.81337236583
# Minibatch step 43/57116: mean batch inertia: 47017.1328125, ewa inertia: 53731.22081154699
# Minibatch step 44/57116: mean batch inertia: 47041.6484375, ewa inertia: 53707.796705627385
# Minibatch step 45/57116: mean batch inertia: 46930.109375, ewa inertia: 53684.06405770231
# Minibatch step 46/57116: mean batch inertia: 47230.40625, ewa inertia: 53661.46602667674
# Minibatch step 47/57116: mean batch inertia: 46515.1875, ewa inertia: 53636.442725368375
# Minibatch step 48/57116: mean batch inertia: 47479.9765625, ewa inertia: 53614.88533613241
# Minibatch step 49/57116: mean batch inertia: 47223.66015625, ewa inertia: 53592.50591825654
# Minibatch step 50/57116: mean batch inertia: 46381.3359375, ewa inertia: 53567.25539400945
# Minibatch step 51/57116: mean batch inertia: 46578.4296875, ewa inertia: 53542.783427125876
# Minibatch step 52/57116: mean batch inertia: 47060.0234375, ewa inertia: 53520.08349233819
# Minibatch step 53/57116: mean batch inertia: 47119.3046875, ewa inertia: 53497.670621633006
# Minibatch step 54/57116: mean batch inertia: 46950.15234375, ewa inertia: 53474.743930198034
# Minibatch step 55/57116: mean batch inertia: 46651.546875, ewa inertia: 53450.8519261065
# Minibatch step 56/57116: mean batch inertia: 46326.8984375, ewa inertia: 53425.90679781536
# Minibatch step 57/57116: mean batch inertia: 47148.76171875, ewa inertia: 53403.92684110315
# Minibatch step 58/57116: mean batch inertia: 46692.1875, ewa inertia: 53380.4251156654
# Minibatch step 59/57116: mean batch inertia: 46839.94140625, ewa inertia: 53357.52305636947
# Minibatch step 60/57116: mean batch inertia: 46036.19921875, ewa inertia: 53331.886819035455
# Minibatch step 61/57116: mean batch inertia: 46690.08984375, ewa inertia: 53308.630002732934
# Minibatch step 62/57116: mean batch inertia: 46712.25, ewa inertia: 53285.532217817796
# Minibatch step 63/57116: mean batch inertia: 46955.859375, ewa inertia: 53263.36833067878
# Minibatch step 64/57116: mean batch inertia: 47108.828125, ewa inertia: 53241.817685345515
# Minibatch step 65/57116: mean batch inertia: 46938.0625, ewa inertia: 53219.744551085736
# Minibatch step 66/57116: mean batch inertia: 46913.1875, ewa inertia: 53197.661605855064
# Minibatch step 67/57116: mean batch inertia: 46703.55859375, ewa inertia: 53174.92195251062
# Minibatch step 68/57116: mean batch inertia: 47252.171875, ewa inertia: 53154.182940000755
# Minibatch step 69/57116: mean batch inertia: 47390.94140625, ewa inertia: 53134.00246020647
# Minibatch step 70/57116: mean batch inertia: 46536.453125, ewa inertia: 53110.90058077435
# Minibatch step 71/57116: mean batch inertia: 47168.6875, ewa inertia: 53090.09341690526
# Minibatch step 72/57116: mean batch inertia: 47167.76953125, ewa inertia: 53069.35589674239
# Minibatch step 73/57116: mean batch inertia: 46788.625, ewa inertia: 53047.36338398498
# Minibatch step 74/57116: mean batch inertia: 46507.28515625, ewa inertia: 53024.4627445176
# Minibatch step 75/57116: mean batch inertia: 46457.3203125, ewa inertia: 53001.467337439935
# Minibatch step 76/57116: mean batch inertia: 46663.6015625, ewa inertia: 52979.274762053145
# Minibatch step 77/57116: mean batch inertia: 47356.86328125, ewa inertia: 52959.587410652195
# Minibatch step 78/57116: mean batch inertia: 46385.8203125, ewa inertia: 52936.56880674332
# Minibatch step 79/57116: mean batch inertia: 46784.0234375, ewa inertia: 52915.02514649928
# Minibatch step 80/57116: mean batch inertia: 46495.73046875, ewa inertia: 52892.54744089225
# Minibatch step 81/57116: mean batch inertia: 46089.3984375, ewa inertia: 52868.72563675712
# Minibatch step 82/57116: mean batch inertia: 46078.109375, ewa inertia: 52844.94771708143
# Minibatch step 83/57116: mean batch inertia: 46318.984375, ewa inertia: 52822.096502085165
# Minibatch step 84/57116: mean batch inertia: 46719.65625, ewa inertia: 52800.72828916508
# Minibatch step 85/57116: mean batch inertia: 46737.5, ewa inertia: 52779.49738026406
# Minibatch step 86/57116: mean batch inertia: 46202.2890625, ewa inertia: 52756.466726632396
# Minibatch step 87/57116: mean batch inertia: 46996.765625, ewa inertia: 52736.29864396192
# Minibatch step 88/57116: mean batch inertia: 46395.73046875, ewa inertia: 52714.09660589102
# Minibatch step 89/57116: mean batch inertia: 46703.35546875, ewa inertia: 52693.049485211384
# Minibatch step 90/57116: mean batch inertia: 46563.5078125, ewa inertia: 52671.58637436482
# Minibatch step 91/57116: mean batch inertia: 46505.0625, ewa inertia: 52649.99376719769
# Minibatch step 92/57116: mean batch inertia: 46362.140625, ewa inertia: 52627.976315292806
# Minibatch step 93/57116: mean batch inertia: 46742.6953125, ewa inertia: 52607.36850393092
# Minibatch step 94/57116: mean batch inertia: 46458.5, ewa inertia: 52585.837718543116
# Minibatch step 95/57116: mean batch inertia: 46628.48828125, ewa inertia: 52564.97755343591
# Minibatch step 96/57116: mean batch inertia: 46564.9375, ewa inertia: 52543.967903509874
# Minibatch step 97/57116: mean batch inertia: 46470.78125, ewa inertia: 52522.70212455018
# Minibatch step 98/57116: mean batch inertia: 47668.26953125, ewa inertia: 52505.703916460494
# Minibatch step 99/57116: mean batch inertia: 46248.7421875, ewa inertia: 52483.79463346317
# Minibatch step 100/57116: mean batch inertia: 46195.0, ewa inertia: 52461.773884846654
# Minibatch step 101/57116: mean batch inertia: 46425.7265625, ewa inertia: 52440.63815240986
# Minibatch step 102/57116: mean batch inertia: 46453.875, ewa inertia: 52419.67499268059
# Minibatch step 103/57116: mean batch inertia: 45921.609375, ewa inertia: 52396.921463936116
# Minibatch step 104/57116: mean batch inertia: 46776.9375, ewa inertia: 52377.24261269168
# Minibatch step 105/57116: mean batch inertia: 46440.671875, ewa inertia: 52356.45520596619
# Minibatch step 106/57116: mean batch inertia: 46448.078125, ewa inertia: 52335.766521724654
# Minibatch step 107/57116: mean batch inertia: 45986.546875, ewa inertia: 52313.534189791346
# Minibatch step 108/57116: mean batch inertia: 46477.859375, ewa inertia: 52293.10007871059
# Minibatch step 109/57116: mean batch inertia: 46540.51953125, ewa inertia: 52272.956929265405
# Minibatch step 110/57116: mean batch inertia: 46348.97265625, ewa inertia: 52252.21359511515
# Minibatch step 111/57116: mean batch inertia: 46140.546875, ewa inertia: 52230.81307493352
# Minibatch step 112/57116: mean batch inertia: 46045.765625, ewa inertia: 52209.15560589303
# Minibatch step 113/57116: mean batch inertia: 46789.65625, ewa inertia: 52190.178768534
# Minibatch step 114/57116: mean batch inertia: 45843.546875, ewa inertia: 52167.95549783831
# Minibatch step 115/57116: mean batch inertia: 46347.734375, ewa inertia: 52147.57549917265
# Minibatch step 116/57116: mean batch inertia: 46669.23046875, ewa inertia: 52128.392608685564
# Minibatch step 117/57116: mean batch inertia: 46554.046875, ewa inertia: 52108.87356358113
# Minibatch step 118/57116: mean batch inertia: 46774.703125, ewa inertia: 52090.19551267442
# Minibatch step 119/57116: mean batch inertia: 47354.24609375, ewa inertia: 52073.612183484474
# Minibatch step 120/57116: mean batch inertia: 46086.50390625, ewa inertia: 52052.64781527132
# Minibatch step 121/57116: mean batch inertia: 46780.125, ewa inertia: 52034.18562875434
# Minibatch step 122/57116: mean batch inertia: 46668.12109375, ewa inertia: 52015.39589795974
# Minibatch step 123/57116: mean batch inertia: 46502.28125, ewa inertia: 51996.09125870331
# Minibatch step 124/57116: mean batch inertia: 46560.6875, ewa inertia: 51977.058730726836
# Minibatch step 125/57116: mean batch inertia: 46788.33984375, ewa inertia: 51958.88999078359
# Minibatch step 126/57116: mean batch inertia: 46766.44140625, ewa inertia: 51940.70819098752
# Minibatch step 127/57116: mean batch inertia: 46814.32421875, ewa inertia: 51922.75772204332
# Minibatch step 128/57116: mean batch inertia: 46081.04296875, ewa inertia: 51902.30246160483
# Minibatch step 129/57116: mean batch inertia: 46276.6171875, ewa inertia: 51882.603646738535
# Minibatch step 130/57116: mean batch inertia: 46753.95703125, ewa inertia: 51864.6452549568
# Minibatch step 131/57116: mean batch inertia: 46758.92578125, ewa inertia: 51846.76714450957
# Minibatch step 132/57116: mean batch inertia: 46618.36328125, ewa inertia: 51828.45944425079
# Minibatch step 133/57116: mean batch inertia: 46743.671875, ewa inertia: 51810.6546286451
# Minibatch step 134/57116: mean batch inertia: 46927.1953125, ewa inertia: 51793.55478101967
# Minibatch step 135/57116: mean batch inertia: 46365.1484375, ewa inertia: 51774.54675508687
# Minibatch step 136/57116: mean batch inertia: 46319.328125, ewa inertia: 51755.44484365505
# Minibatch step 137/57116: mean batch inertia: 46726.4296875, ewa inertia: 51737.83531989145
# Minibatch step 138/57116: mean batch inertia: 46252.87109375, ewa inertia: 51718.62925172828
# Minibatch step 139/57116: mean batch inertia: 46797.7109375, ewa inertia: 51701.398238239075
# Minibatch step 140/57116: mean batch inertia: 46427.1015625, ewa inertia: 51682.92984039899
# Minibatch step 141/57116: mean batch inertia: 47300.2109375, ewa inertia: 51667.583377866395
# Minibatch step 142/57116: mean batch inertia: 46354.54296875, ewa inertia: 51648.979315552766
# Minibatch step 143/57116: mean batch inertia: 46688.375, ewa inertia: 51631.60933815876
# Minibatch step 144/57116: mean batch inertia: 45813.1015625, ewa inertia: 51611.2353389238
# Minibatch step 145/57116: mean batch inertia: 46398.015625, ewa inertia: 51592.98080725374
# Minibatch step 146/57116: mean batch inertia: 46570.3515625, ewa inertia: 51575.39364430137
# Minibatch step 147/57116: mean batch inertia: 46637.6875, ewa inertia: 51558.10384679911
# Minibatch step 148/57116: mean batch inertia: 46508.16796875, ewa inertia: 51540.42106735067
# Minibatch step 149/57116: mean batch inertia: 46548.0546875, ewa inertia: 51522.93987239047
# Minibatch step 150/57116: mean batch inertia: 45487.58203125, ewa inertia: 51501.80655423069
# Minibatch step 151/57116: mean batch inertia: 46278.5625, ewa inertia: 51483.516921481525
# Minibatch step 152/57116: mean batch inertia: 46361.5, ewa inertia: 51465.581744136514
# Minibatch step 153/57116: mean batch inertia: 45853.9140625, ewa inertia: 51445.932013060985
# Minibatch step 154/57116: mean batch inertia: 46902.13671875, ewa inertia: 51430.021527861085
# Minibatch step 155/57116: mean batch inertia: 46090.8203125, ewa inertia: 51411.325861262136
# Minibatch step 156/57116: mean batch inertia: 46631.8671875, ewa inertia: 51394.59018072044
# Minibatch step 157/57116: mean batch inertia: 46458.2265625, ewa inertia: 51377.3050841873
# Minibatch step 158/57116: mean batch inertia: 46761.13671875, ewa inertia: 51361.14117853105
# Minibatch step 159/57116: mean batch inertia: 46292.0, ewa inertia: 51343.39115009156
# Minibatch step 160/57116: mean batch inertia: 46641.7578125, ewa inertia: 51326.927981575405
# Minibatch step 161/57116: mean batch inertia: 47036.0546875, ewa inertia: 51311.90312424402
# Minibatch step 162/57116: mean batch inertia: 47057.15625, ewa inertia: 51297.004766640464
# Minibatch step 163/57116: mean batch inertia: 46571.3046875, ewa inertia: 51280.457326384414
# Minibatch step 164/57116: mean batch inertia: 45885.34375, ewa inertia: 51261.56587790382
# Minibatch step 165/57116: mean batch inertia: 46547.546875, ewa inertia: 51245.05933992847
# Minibatch step 166/57116: mean batch inertia: 46964.99609375, ewa inertia: 51230.07233489806
# Minibatch step 167/57116: mean batch inertia: 45651.53125, ewa inertia: 51210.538599414984
# Minibatch step 168/57116: mean batch inertia: 46017.3203125, ewa inertia: 51192.354104440645
# Minibatch step 169/57116: mean batch inertia: 46981.64453125, ewa inertia: 51177.60994718752
# Minibatch step 170/57116: mean batch inertia: 46578.87109375, ewa inertia: 51161.507072448105
# Minibatch step 171/57116: mean batch inertia: 45893.99609375, ewa inertia: 51143.06243530263
# Minibatch step 172/57116: mean batch inertia: 46055.7109375, ewa inertia: 51125.24864188332
# Minibatch step 173/57116: mean batch inertia: 46198.8828125, ewa inertia: 51107.99855345705
# Minibatch step 174/57116: mean batch inertia: 46749.09375, ewa inertia: 51092.73547801656
# Minibatch step 175/57116: mean batch inertia: 47086.859375, ewa inertia: 51078.70856255902
# Minibatch step 176/57116: mean batch inertia: 46467.65625, ewa inertia: 51062.56257119651
# Minibatch step 177/57116: mean batch inertia: 47024.3046875, ewa inertia: 51048.42226818321
# Minibatch step 178/57116: mean batch inertia: 47070.5, ewa inertia: 51034.4932354529
# Minibatch step 179/57116: mean batch inertia: 46095.125, ewa inertia: 51017.197617997284
# Minibatch step 180/57116: mean batch inertia: 45846.328125, ewa inertia: 50999.09137922328
# Minibatch step 181/57116: mean batch inertia: 46030.9375, ewa inertia: 50981.69496639077
# Minibatch step 182/57116: mean batch inertia: 46331.0703125, ewa inertia: 50965.41040911358
# Minibatch step 183/57116: mean batch inertia: 47190.4609375, ewa inertia: 50952.19210287217
# Minibatch step 184/57116: mean batch inertia: 46299.1015625, ewa inertia: 50935.898911084
# Minibatch step 185/57116: mean batch inertia: 46711.73046875, ewa inertia: 50921.10762645729
# Minibatch step 186/57116: mean batch inertia: 46361.140625, ewa inertia: 50905.140514651095
# Minibatch step 187/57116: mean batch inertia: 46906.8359375, ewa inertia: 50891.140111534536
# Minibatch step 188/57116: mean batch inertia: 46748.625, ewa inertia: 50876.63474298174
# Minibatch step 189/57116: mean batch inertia: 46687.0625, ewa inertia: 50861.96459988587
# Minibatch step 190/57116: mean batch inertia: 45725.375, ewa inertia: 50843.978395069535
# Minibatch step 191/57116: mean batch inertia: 46125.28125, ewa inertia: 50827.455476182
# Minibatch step 192/57116: mean batch inertia: 46430.38671875, ewa inertia: 50812.058766414804
# Minibatch step 193/57116: mean batch inertia: 46287.13671875, ewa inertia: 50796.214367491244
# Minibatch step 194/57116: mean batch inertia: 46841.8984375, ewa inertia: 50782.367994359374
# Minibatch step 195/57116: mean batch inertia: 46727.7890625, ewa inertia: 50768.17054180953
# Minibatch step 196/57116: mean batch inertia: 45676.6796875, ewa inertia: 50750.342254081785
# Minibatch step 197/57116: mean batch inertia: 46114.46875, ewa inertia: 50734.1093492087
# Minibatch step 198/57116: mean batch inertia: 46643.28125, ewa inertia: 50719.78496712016
# Minibatch step 199/57116: mean batch inertia: 46214.03515625, ewa inertia: 50704.00770141233
# Minibatch step 200/57116: mean batch inertia: 46655.43359375, ewa inertia: 50689.8312752645
# Minibatch step 201/57116: mean batch inertia: 46663.1640625, ewa inertia: 50675.73155797005
# Minibatch step 202/57116: mean batch inertia: 46259.88671875, ewa inertia: 50660.269102157516
# Minibatch step 203/57116: mean batch inertia: 46334.625, ewa inertia: 50645.12249188799
# Minibatch step 204/57116: mean batch inertia: 46338.984375, ewa inertia: 50630.04418348284
# Minibatch step 205/57116: mean batch inertia: 46316.48828125, ewa inertia: 50614.93990107219
# Minibatch step 206/57116: mean batch inertia: 45971.1015625, ewa inertia: 50598.679106654556
# Minibatch step 207/57116: mean batch inertia: 46567.5, ewa inertia: 50584.56359058039
# Minibatch step 208/57116: mean batch inertia: 46599.53515625, ewa inertia: 50570.609675005675
# Minibatch step 209/57116: mean batch inertia: 45989.2109375, ewa inertia: 50554.56751815516
# Minibatch step 210/57116: mean batch inertia: 46302.85546875, ewa inertia: 50539.67978724858
# Minibatch step 211/57116: mean batch inertia: 46852.71875, ewa inertia: 50526.76957998435
# Minibatch step 212/57116: mean batch inertia: 46367.7109375, ewa inertia: 50512.20628285263
# Minibatch step 213/57116: mean batch inertia: 46299.16796875, ewa inertia: 50497.453971315386
# Minibatch step 214/57116: mean batch inertia: 46151.85546875, ewa inertia: 50482.23748901779
# Minibatch step 215/57116: mean batch inertia: 47062.67578125, ewa inertia: 50470.26360322023
# Minibatch step 216/57116: mean batch inertia: 46350.171875, ewa inertia: 50455.836752048875
# Minibatch step 217/57116: mean batch inertia: 46578.91015625, ewa inertia: 50442.26136424459
# Minibatch step 218/57116: mean batch inertia: 45938.57421875, ewa inertia: 50426.49132113479
# Minibatch step 219/57116: mean batch inertia: 46577.265625, ewa inertia: 50413.01293038375
# Minibatch step 220/57116: mean batch inertia: 45883.640625, ewa inertia: 50397.15294850476
# Minibatch step 221/57116: mean batch inertia: 46203.390625, ewa inertia: 50382.46813348601
# Minibatch step 222/57116: mean batch inertia: 46974.59375, ewa inertia: 50370.5351718472
# Minibatch step 223/57116: mean batch inertia: 46791.953125, ewa inertia: 50358.00446282422
# Minibatch step 224/57116: mean batch inertia: 47396.41015625, ewa inertia: 50347.634188784396
# Minibatch step 225/57116: mean batch inertia: 46392.15625, ewa inertia: 50333.78374678003
# Minibatch step 226/57116: mean batch inertia: 46316.25, ewa inertia: 50319.716011092576
# Minibatch step 227/57116: mean batch inertia: 46291.01953125, ewa inertia: 50305.60918814708
# Minibatch step 228/57116: mean batch inertia: 46802.453125, ewa inertia: 50293.34258961315
# Minibatch step 229/57116: mean batch inertia: 46361.859375, ewa inertia: 50279.57616717373
# Minibatch step 230/57116: mean batch inertia: 46082.84375, ewa inertia: 50264.880952119696
# Minibatch step 231/57116: mean batch inertia: 45903.109375, ewa inertia: 50249.60783842771
# Minibatch step 232/57116: mean batch inertia: 46941.4609375, ewa inertia: 50238.02408104053
# Minibatch step 233/57116: mean batch inertia: 46204.3984375, ewa inertia: 50223.89999820963
# Minibatch step 234/57116: mean batch inertia: 46070.9609375, ewa inertia: 50209.35812931332
# Minibatch step 235/57116: mean batch inertia: 46272.85546875, ewa inertia: 50195.574130857516
# Minibatch step 236/57116: mean batch inertia: 46091.43359375, ewa inertia: 50181.20313413684
# Minibatch step 237/57116: mean batch inertia: 45900.3046875, ewa inertia: 50166.21320458109
# Minibatch step 238/57116: mean batch inertia: 46590.70703125, ewa inertia: 50153.69326599051
# Minibatch step 239/57116: mean batch inertia: 46276.83203125, ewa inertia: 50140.11810705352
# Minibatch step 240/57116: mean batch inertia: 46281.57421875, ewa inertia: 50126.607087861055
# Minibatch step 241/57116: mean batch inertia: 45784.09375, ewa inertia: 50111.401408529746
# Minibatch step 242/57116: mean batch inertia: 46170.609375, ewa inertia: 50097.602390470136
# Minibatch step 243/57116: mean batch inertia: 46284.7578125, ewa inertia: 50084.25139129478
# Minibatch step 244/57116: mean batch inertia: 46615.0859375, ewa inertia: 50072.103813766866
# Minibatch step 245/57116: mean batch inertia: 46101.421875, ewa inertia: 50058.200133665036
# Minibatch step 246/57116: mean batch inertia: 46475.05078125, ewa inertia: 50045.653431833634
# Minibatch step 247/57116: mean batch inertia: 46135.34765625, ewa inertia: 50031.961163995904
# Minibatch step 248/57116: mean batch inertia: 46094.1171875, ewa inertia: 50018.17246880842
# Minibatch step 249/57116: mean batch inertia: 45897.02734375, ewa inertia: 50003.74192907856
# Minibatch step 250/57116: mean batch inertia: 46435.27734375, ewa inertia: 49991.24664720652
# Minibatch step 251/57116: mean batch inertia: 46837.671875, ewa inertia: 49980.204137258326
# Minibatch step 252/57116: mean batch inertia: 46397.6640625, ewa inertia: 49967.659568864394
# Minibatch step 253/57116: mean batch inertia: 47186.328125, ewa inertia: 49957.92050055094
# Minibatch step 254/57116: mean batch inertia: 46597.13671875, ewa inertia: 49946.152430654096
# Minibatch step 255/57116: mean batch inertia: 46248.84375, ewa inertia: 49933.2059902375
# Minibatch step 256/57116: mean batch inertia: 45814.859375, ewa inertia: 49918.7852497275
# Minibatch step 257/57116: mean batch inertia: 46352.5390625, ewa inertia: 49906.297735764856
# Minibatch step 258/57116: mean batch inertia: 47209.234375, ewa inertia: 49896.85373930261
# Minibatch step 259/57116: mean batch inertia: 45933.4375, ewa inertia: 49882.97550066465
# Minibatch step 260/57116: mean batch inertia: 46650.70703125, ewa inertia: 49871.65743805098
# Minibatch step 261/57116: mean batch inertia: 46486.9375, ewa inertia: 49859.805553669736
# Minibatch step 262/57116: mean batch inertia: 46390.64453125, ewa inertia: 49847.657991658656
# Minibatch step 263/57116: mean batch inertia: 46341.91015625, ewa inertia: 49835.382317814
# Minibatch step 264/57116: mean batch inertia: 45916.4375, ewa inertia: 49821.65979963605
# Minibatch step 265/57116: mean batch inertia: 46803.390625, ewa inertia: 49811.09107373141
# Minibatch step 266/57116: mean batch inertia: 46220.15234375, ewa inertia: 49798.51709673279
# Minibatch step 267/57116: mean batch inertia: 46705.47265625, ewa inertia: 49787.68653888293
# Minibatch step 268/57116: mean batch inertia: 46137.3984375, ewa inertia: 49774.90474501885
# Minibatch step 269/57116: mean batch inertia: 46156.515625, ewa inertia: 49762.23464814771
# Minibatch step 270/57116: mean batch inertia: 46298.390625, ewa inertia: 49750.105704061236
# Minibatch step 271/57116: mean batch inertia: 46117.72265625, ewa inertia: 49737.38660626321
# Minibatch step 272/57116: mean batch inertia: 46606.4609375, ewa inertia: 49726.423404074674
# Minibatch step 273/57116: mean batch inertia: 45951.453125, ewa inertia: 49713.205024974166
# Minibatch step 274/57116: mean batch inertia: 46405.08203125, ewa inertia: 49701.621351300084
# Minibatch step 275/57116: mean batch inertia: 45893.3046875, ewa inertia: 49688.28620700082
# Minibatch step 276/57116: mean batch inertia: 45916.5234375, ewa inertia: 49675.079059267555
# Minibatch step 277/57116: mean batch inertia: 46547.1796875, ewa inertia: 49664.126453915014
# Minibatch step 278/57116: mean batch inertia: 46020.8203125, ewa inertia: 49651.36910797686
# Minibatch step 279/57116: mean batch inertia: 46790.59375, ewa inertia: 49641.351860049705
# Minibatch step 280/57116: mean batch inertia: 46562.7734375, ewa inertia: 49630.57195619047
# Minibatch step 281/57116: mean batch inertia: 46473.01171875, ewa inertia: 49619.51549079721
# Minibatch step 282/57116: mean batch inertia: 46071.02734375, ewa inertia: 49607.09015812073
# Minibatch step 283/57116: mean batch inertia: 46476.109375, ewa inertia: 49596.12676294459
# Minibatch step 284/57116: mean batch inertia: 46509.40625, ewa inertia: 49585.318348864195
# Minibatch step 285/57116: mean batch inertia: 46529.25, ewa inertia: 49574.61726594011
# Minibatch step 286/57116: mean batch inertia: 46471.74609375, ewa inertia: 49563.75229895444
# Minibatch step 287/57116: mean batch inertia: 46029.69140625, ewa inertia: 49551.377484534576
# Minibatch step 288/57116: mean batch inertia: 46148.8671875, ewa inertia: 49539.46330570014
# Minibatch step 289/57116: mean batch inertia: 46459.65625, ewa inertia: 49528.67909967756
# Minibatch step 290/57116: mean batch inertia: 45877.2265625, ewa inertia: 49515.893228442634
# Minibatch step 291/57116: mean batch inertia: 47477.49609375, ewa inertia: 49508.755607721985
# Minibatch step 292/57116: mean batch inertia: 46320.0078125, ewa inertia: 49497.5899364459
# Minibatch step 293/57116: mean batch inertia: 46161.2890625, ewa inertia: 49485.90759553063
# Minibatch step 294/57116: mean batch inertia: 46359.78125, ewa inertia: 49474.96119858008
# Minibatch step 295/57116: mean batch inertia: 46975.03125, ewa inertia: 49466.20748150628
# Minibatch step 296/57116: mean batch inertia: 46273.68359375, ewa inertia: 49455.02858792143
# Minibatch step 297/57116: mean batch inertia: 47069.9296875, ewa inertia: 49446.67696151719
# Minibatch step 298/57116: mean batch inertia: 46435.234375, ewa inertia: 49436.132139490735
# Minibatch step 299/57116: mean batch inertia: 46559.28125, ewa inertia: 49426.05860172444
# Minibatch step 300/57116: mean batch inertia: 46936.9453125, ewa inertia: 49417.342760102205
# Minibatch step 301/57116: mean batch inertia: 46741.4296875, ewa inertia: 49407.97282317059
# Minibatch step 302/57116: mean batch inertia: 45858.60546875, ewa inertia: 49395.544411874806
# Minibatch step 303/57116: mean batch inertia: 46768.76953125, ewa inertia: 49386.34653649649
# Minibatch step 304/57116: mean batch inertia: 46116.328125, ewa inertia: 49374.89628925391
# Minibatch step 305/57116: mean batch inertia: 46513.86328125, ewa inertia: 49364.87813914331
# Minibatch step 306/57116: mean batch inertia: 46164.703125, ewa inertia: 49353.672454489475
# Minibatch step 307/57116: mean batch inertia: 46281.1796875, ewa inertia: 49342.91386007013
# Minibatch step 308/57116: mean batch inertia: 45990.4453125, ewa inertia: 49331.17490667229
# Minibatch step 309/57116: mean batch inertia: 46339.55078125, ewa inertia: 49320.69948067086
# Minibatch step 310/57116: mean batch inertia: 46338.984375, ewa inertia: 49310.25875194382
# Minibatch step 311/57116: mean batch inertia: 45712.51953125, ewa inertia: 49297.66096244929
# Minibatch step 312/57116: mean batch inertia: 46161.09765625, ewa inertia: 49286.67801959437
# Minibatch step 313/57116: mean batch inertia: 46545.4921875, ewa inertia: 49277.07952455074
# Minibatch step 314/57116: mean batch inertia: 45925.6328125, ewa inertia: 49265.34414919677
# Minibatch step 315/57116: mean batch inertia: 46748.1484375, ewa inertia: 49256.52997458675
# Minibatch step 316/57116: mean batch inertia: 46039.42578125, ewa inertia: 49245.265010973904
# Minibatch step 317/57116: mean batch inertia: 46293.97265625, ewa inertia: 49234.93081009359
# Minibatch step 318/57116: mean batch inertia: 46371.0078125, ewa inertia: 49224.90254043894
# Minibatch step 319/57116: mean batch inertia: 46705.953125, ewa inertia: 49216.082225086306
# Minibatch step 320/57116: mean batch inertia: 46489.5859375, ewa inertia: 49206.53516673058
# Minibatch step 321/57116: mean batch inertia: 45873.1875, ewa inertia: 49194.86316672124
# Minibatch step 322/57116: mean batch inertia: 46094.6015625, ewa inertia: 49184.007337359486
# Minibatch step 323/57116: mean batch inertia: 46168.421875, ewa inertia: 49173.44800870135
# Minibatch step 324/57116: mean batch inertia: 46473.1640625, ewa inertia: 49163.99273508562
# Minibatch step 325/57116: mean batch inertia: 46315.453125, ewa inertia: 49154.01833166909
# Minibatch step 326/57116: mean batch inertia: 45807.88671875, ewa inertia: 49142.30156758622
# Minibatch step 327/57116: mean batch inertia: 46116.0703125, ewa inertia: 49131.70496178054
# Minibatch step 328/57116: mean batch inertia: 46082.67578125, ewa inertia: 49121.02852710232
# Minibatch step 329/57116: mean batch inertia: 46222.7109375, ewa inertia: 49110.87982186207
# Minibatch step 330/57116: mean batch inertia: 45881.5078125, ewa inertia: 49099.57190144931
# Minibatch step 331/57116: mean batch inertia: 46151.1328125, ewa inertia: 49089.24769152148
# Minibatch step 332/57116: mean batch inertia: 46081.0234375, ewa inertia: 49078.71413875965
# Minibatch step 333/57116: mean batch inertia: 45887.77734375, ewa inertia: 49067.54080251486
# Minibatch step 334/57116: mean batch inertia: 47226.79296875, ewa inertia: 49061.09526761091
# Minibatch step 335/57116: mean batch inertia: 46261.3515625, ewa inertia: 49051.29172720065
# Minibatch step 336/57116: mean batch inertia: 46242.046875, ewa inertia: 49041.45491771678
# Minibatch step 337/57116: mean batch inertia: 46285.49609375, ewa inertia: 49031.8046937872
# Minibatch step 338/57116: mean batch inertia: 46821.6875, ewa inertia: 49024.06578069271
# Minibatch step 339/57116: mean batch inertia: 45704.625, ewa inertia: 49012.44247682617
# Minibatch step 340/57116: mean batch inertia: 46572.6796875, ewa inertia: 49003.899440171444
# Minibatch step 341/57116: mean batch inertia: 46032.08203125, ewa inertia: 48993.49336907035
# Minibatch step 342/57116: mean batch inertia: 45869.98828125, ewa inertia: 48982.55615067633
# Minibatch step 343/57116: mean batch inertia: 45719.81640625, ewa inertia: 48971.13139030479
# Minibatch step 344/57116: mean batch inertia: 45953.6484375, ewa inertia: 48960.56541742268
# Minibatch step 345/57116: mean batch inertia: 46643.078125, ewa inertia: 48952.45053880717
# Minibatch step 346/57116: mean batch inertia: 45935.328125, ewa inertia: 48941.88582838298
# Minibatch step 347/57116: mean batch inertia: 46339.9765625, ewa inertia: 48932.77502206692
# Minibatch step 348/57116: mean batch inertia: 46063.265625, ewa inertia: 48922.727191159975
# Minibatch step 349/57116: mean batch inertia: 45811.5078125, ewa inertia: 48911.8329922202
# Minibatch step 350/57116: mean batch inertia: 45823.3046875, ewa inertia: 48901.01824800335
# Minibatch step 351/57116: mean batch inertia: 46081.28515625, ewa inertia: 48891.14471305775
# Minibatch step 352/57116: mean batch inertia: 46318.0703125, ewa inertia: 48882.13487447202
# Minibatch step 353/57116: mean batch inertia: 45715.63671875, ewa inertia: 48871.04711219866
# Minibatch step 354/57116: mean batch inertia: 46808.453125, ewa inertia: 48863.824764143545
# Minibatch step 355/57116: mean batch inertia: 46394.16015625, ewa inertia: 48855.17702373107
# Minibatch step 356/57116: mean batch inertia: 46383.9375, ewa inertia: 48846.52376861701
# Minibatch step 357/57116: mean batch inertia: 46483.9453125, ewa inertia: 48838.25099946151
# Minibatch step 358/57116: mean batch inertia: 46197.0234375, ewa inertia: 48829.00251679179
# Minibatch step 359/57116: mean batch inertia: 46432.1328125, ewa inertia: 48820.60967391791
# Minibatch step 360/57116: mean batch inertia: 46348.29296875, ewa inertia: 48811.95264696155
# Minibatch step 361/57116: mean batch inertia: 46404.90625, ewa inertia: 48803.52416953382
# Minibatch step 362/57116: mean batch inertia: 47193.515625, ewa inertia: 48797.88658785148
# Minibatch step 363/57116: mean batch inertia: 46357.6328125, ewa inertia: 48789.34183196748
# Minibatch step 364/57116: mean batch inertia: 46746.65234375, ewa inertia: 48782.189181206355
# Minibatch step 365/57116: mean batch inertia: 45845.9296875, ewa inertia: 48771.907619165875
# Minibatch step 366/57116: mean batch inertia: 47088.34765625, ewa inertia: 48766.01249094417
# Minibatch step 367/57116: mean batch inertia: 45979.4609375, ewa inertia: 48756.2551439736
# Minibatch step 368/57116: mean batch inertia: 46358.5, ewa inertia: 48747.85920065746
# Minibatch step 369/57116: mean batch inertia: 46001.2265625, ewa inertia: 48738.24163315971
# Minibatch step 370/57116: mean batch inertia: 46250.875, ewa inertia: 48729.53190760205
# Minibatch step 371/57116: mean batch inertia: 45892.3515625, ewa inertia: 48719.597279616784
# Minibatch step 372/57116: mean batch inertia: 45933.09375, ewa inertia: 48709.84010080572
# Minibatch step 373/57116: mean batch inertia: 46535.5390625, ewa inertia: 48702.226601022085
# Minibatch step 374/57116: mean batch inertia: 46210.9375, ewa inertia: 48693.50314061001
# Minibatch step 375/57116: mean batch inertia: 46004.26953125, ewa inertia: 48684.086560687414
# Minibatch step 376/57116: mean batch inertia: 46525.3515625, ewa inertia: 48676.52756671553
# Minibatch step 377/57116: mean batch inertia: 46290.94921875, ewa inertia: 48668.17426148498
# Minibatch step 378/57116: mean batch inertia: 45504.7890625, ewa inertia: 48657.097399494065
# Minibatch step 379/57116: mean batch inertia: 46607.578125, ewa inertia: 48649.92083365613
# Minibatch step 380/57116: mean batch inertia: 46035.296875, ewa inertia: 48640.76550576326
# Minibatch step 381/57116: mean batch inertia: 46290.0859375, ewa inertia: 48632.53440157435
# Minibatch step 382/57116: mean batch inertia: 46566.359375, ewa inertia: 48625.29951420566
# Minibatch step 383/57116: mean batch inertia: 45979.05078125, ewa inertia: 48616.03344947918
# Minibatch step 384/57116: mean batch inertia: 46815.984375, ewa inertia: 48609.73042473807
# Minibatch step 385/57116: mean batch inertia: 46431.234375, ewa inertia: 48602.10223576555
# Minibatch step 386/57116: mean batch inertia: 46082.09375, ewa inertia: 48593.2782119882
# Minibatch step 387/57116: mean batch inertia: 45938.484375, ewa inertia: 48583.98222585408
# Minibatch step 388/57116: mean batch inertia: 46331.921875, ewa inertia: 48576.09644523223
# Minibatch step 389/57116: mean batch inertia: 46934.26171875, ewa inertia: 48570.347421470295
# Minibatch step 390/57116: mean batch inertia: 45939.1328125, ewa inertia: 48561.13400000604
# Minibatch step 391/57116: mean batch inertia: 46073.54296875, ewa inertia: 48552.42348869939
# Minibatch step 392/57116: mean batch inertia: 46129.7109375, ewa inertia: 48543.940154901815
# Minibatch step 393/57116: mean batch inertia: 46507.65625, ewa inertia: 48536.8099338348
# Minibatch step 394/57116: mean batch inertia: 46096.4609375, ewa inertia: 48528.264844526435
# Minibatch step 395/57116: mean batch inertia: 46704.2890625, ewa inertia: 48521.87803838637
# Minibatch step 396/57116: mean batch inertia: 45764.671875, ewa inertia: 48512.22344679186
# Minibatch step 397/57116: mean batch inertia: 46424.84375, ewa inertia: 48504.91430946915
# Minibatch step 398/57116: mean batch inertia: 46504.8828125, ewa inertia: 48497.911029288
# Minibatch step 399/57116: mean batch inertia: 46304.62109375, ewa inertia: 48490.23103826768
# Minibatch step 400/57116: mean batch inertia: 45609.34375, ewa inertia: 48480.143366708195
# Minibatch step 401/57116: mean batch inertia: 46840.25, ewa inertia: 48474.401140782415
# Minibatch step 402/57116: mean batch inertia: 45795.67578125, ewa inertia: 48465.02135638922
# Minibatch step 403/57116: mean batch inertia: 46078.4453125, ewa inertia: 48456.66455764164
# Minibatch step 404/57116: mean batch inertia: 46401.33984375, ewa inertia: 48449.4676635645
# Minibatch step 405/57116: mean batch inertia: 45605.2578125, ewa inertia: 48439.50842116698
# Minibatch step 406/57116: mean batch inertia: 46627.4921875, ewa inertia: 48433.163492401414
# Minibatch step 407/57116: mean batch inertia: 46308.60546875, ewa inertia: 48425.72417200907
# Minibatch step 408/57116: mean batch inertia: 46313.4453125, ewa inertia: 48418.32784815303
# Minibatch step 409/57116: mean batch inertia: 46398.328125, ewa inertia: 48411.25464753168
# Minibatch step 410/57116: mean batch inertia: 45927.89453125, ewa inertia: 48402.55895113321
# Minibatch step 411/57116: mean batch inertia: 46479.75390625, ewa inertia: 48395.8260859341
# Minibatch step 412/57116: mean batch inertia: 46612.9375, ewa inertia: 48389.58315010134
# Minibatch step 413/57116: mean batch inertia: 46262.96484375, ewa inertia: 48382.1366154541
# Minibatch step 414/57116: mean batch inertia: 46474.6953125, ewa inertia: 48375.45754770245
# Minibatch step 415/57116: mean batch inertia: 46222.8515625, ewa inertia: 48367.92001499016
# Minibatch step 416/57116: mean batch inertia: 45894.51171875, ewa inertia: 48359.259165734926
# Minibatch step 417/57116: mean batch inertia: 46434.76171875, ewa inertia: 48352.5203744461
# Minibatch step 418/57116: mean batch inertia: 46246.1171875, ewa inertia: 48345.14462475666
# Minibatch step 419/57116: mean batch inertia: 46994.9609375, ewa inertia: 48340.41684188313
# Minibatch step 420/57116: mean batch inertia: 46239.0078125, ewa inertia: 48333.058579660625
# Minibatch step 421/57116: mean batch inertia: 46132.8203125, ewa inertia: 48325.3542584669
# Minibatch step 422/57116: mean batch inertia: 46667.96875, ewa inertia: 48319.55078232087
# Minibatch step 423/57116: mean batch inertia: 45606.71875, ewa inertia: 48310.05157051568
# Minibatch step 424/57116: mean batch inertia: 46076.32421875, ewa inertia: 48302.22998444745
# Minibatch step 425/57116: mean batch inertia: 45995.4765625, ewa inertia: 48294.15269139121
# Minibatch step 426/57116: mean batch inertia: 46422.96875, ewa inertia: 48287.60058187099
# Minibatch step 427/57116: mean batch inertia: 46264.84375, ewa inertia: 48280.51772699926
# Minibatch step 428/57116: mean batch inertia: 46669.09375, ewa inertia: 48274.8751890599
# Minibatch step 429/57116: mean batch inertia: 46863.86328125, ewa inertia: 48269.934411005
# Minibatch step 430/57116: mean batch inertia: 45900.3671875, ewa inertia: 48261.637170086826
# Minibatch step 431/57116: mean batch inertia: 45146.03515625, ewa inertia: 48250.72762497769
# Minibatch step 432/57116: mean batch inertia: 46116.3515625, ewa inertia: 48243.253925888384
# Minibatch step 433/57116: mean batch inertia: 46544.78125, ewa inertia: 48237.306579535434
# Minibatch step 434/57116: mean batch inertia: 46798.171875, ewa inertia: 48232.26732711888
# Minibatch step 435/57116: mean batch inertia: 46359.6875, ewa inertia: 48225.710329786205
# Minibatch step 436/57116: mean batch inertia: 45776.70703125, ewa inertia: 48217.13493670354
# Minibatch step 437/57116: mean batch inertia: 45766.875, ewa inertia: 48208.555143395584
# Minibatch step 438/57116: mean batch inertia: 46443.6328125, ewa inertia: 48202.375117931
# Minibatch step 439/57116: mean batch inertia: 46586.34375, ewa inertia: 48196.716446820916
# Minibatch step 440/57116: mean batch inertia: 45749.6875, ewa inertia: 48188.14796709849
# Minibatch step 441/57116: mean batch inertia: 46322.578125, ewa inertia: 48181.61551582383
# Minibatch step 442/57116: mean batch inertia: 46176.6328125, ewa inertia: 48174.59489857305
# Minibatch step 443/57116: mean batch inertia: 46824.8828125, ewa inertia: 48169.868767051135
# Minibatch step 444/57116: mean batch inertia: 46670.90625, ewa inertia: 48164.62002246693
# Minibatch step 445/57116: mean batch inertia: 46374.84765625, ewa inertia: 48158.35298249276
# Minibatch step 446/57116: mean batch inertia: 45405.5078125, ewa inertia: 48148.71366128707
# Minibatch step 447/57116: mean batch inertia: 46172.1953125, ewa inertia: 48141.79271439162
# Minibatch step 448/57116: mean batch inertia: 46215.01171875, ewa inertia: 48135.04592706319
# Minibatch step 449/57116: mean batch inertia: 46445.1640625, ewa inertia: 48129.12866216585
# Minibatch step 450/57116: mean batch inertia: 46148.4296875, ewa inertia: 48122.19307645376
# Minibatch step 451/57116: mean batch inertia: 46538.734375, ewa inertia: 48116.64846130226
# Minibatch step 452/57116: mean batch inertia: 45441.53125, ewa inertia: 48107.281311146595
# Minibatch step 453/57116: mean batch inertia: 46087.0703125, ewa inertia: 48100.20737072615
# Minibatch step 454/57116: mean batch inertia: 46473.3515625, ewa inertia: 48094.51079691888
# Minibatch step 455/57116: mean batch inertia: 46104.359375, ewa inertia: 48087.54211265979
# Minibatch step 456/57116: mean batch inertia: 45547.328125, ewa inertia: 48078.647337601185
# Minibatch step 457/57116: mean batch inertia: 45723.98046875, ewa inertia: 48070.40227154056
# Minibatch step 458/57116: mean batch inertia: 46379.5234375, ewa inertia: 48064.481515669904
# Minibatch step 459/57116: mean batch inertia: 46944.8046875, ewa inertia: 48060.56087214409
# Minibatch step 460/57116: mean batch inertia: 46699.609375, ewa inertia: 48055.79538486956
# Minibatch step 461/57116: mean batch inertia: 46947.8515625, ewa inertia: 48051.91582546022
# Minibatch step 462/57116: mean batch inertia: 46656.66796875, ewa inertia: 48047.03024656934
# Minibatch step 463/57116: mean batch inertia: 46137.8046875, ewa inertia: 48040.344931093336
# Minibatch step 464/57116: mean batch inertia: 45709.6796875, ewa inertia: 48032.18390876239
# Minibatch step 465/57116: mean batch inertia: 46100.94140625, ewa inertia: 48025.42149908867
# Minibatch step 466/57116: mean batch inertia: 45631.36328125, ewa inertia: 48017.03850087342
# Minibatch step 467/57116: mean batch inertia: 46187.75, ewa inertia: 48010.63309179702
# Minibatch step 468/57116: mean batch inertia: 45723.34375, ewa inertia: 48002.62395387082
# Minibatch step 469/57116: mean batch inertia: 46659.296875, ewa inertia: 47997.920179994
# Minibatch step 470/57116: mean batch inertia: 45679.046875, ewa inertia: 47989.800448137736
# Minibatch step 471/57116: mean batch inertia: 45640.55078125, ewa inertia: 47981.57435086995
# Minibatch step 472/57116: mean batch inertia: 46503.4921875, ewa inertia: 47976.39872061786
# Minibatch step 473/57116: mean batch inertia: 45805.765625, ewa inertia: 47968.798064447124
# Minibatch step 474/57116: mean batch inertia: 46230.9296875, ewa inertia: 47962.71277070041
# Minibatch step 475/57116: mean batch inertia: 46316.765625, ewa inertia: 47956.949346953246
# Minibatch step 476/57116: mean batch inertia: 46005.078125, ewa inertia: 47950.11470406608
# Minibatch step 477/57116: mean batch inertia: 46647.58203125, ewa inertia: 47945.55377526738
# Minibatch step 478/57116: mean batch inertia: 46241.9140625, ewa inertia: 47939.58833609588
# Minibatch step 479/57116: mean batch inertia: 45809.8828125, ewa inertia: 47932.13099129521
# Minibatch step 480/57116: mean batch inertia: 46146.4453125, ewa inertia: 47925.8782612042
# Minibatch step 481/57116: mean batch inertia: 46316.7109375, ewa inertia: 47920.243625128045
# Minibatch step 482/57116: mean batch inertia: 45632.03515625, ewa inertia: 47912.23126880029
# Minibatch step 483/57116: mean batch inertia: 45959.125, ewa inertia: 47905.39230129168
# Minibatch step 484/57116: mean batch inertia: 45970.578125, ewa inertia: 47898.61738509882
# Minibatch step 485/57116: mean batch inertia: 45976.25, ewa inertia: 47891.88605240263
# Minibatch step 486/57116: mean batch inertia: 45877.5625, ewa inertia: 47884.832727375324
# Minibatch step 487/57116: mean batch inertia: 46290.5625, ewa inertia: 47879.250254747414
# Minibatch step 488/57116: mean batch inertia: 46467.8984375, ewa inertia: 47874.30828647075
# Minibatch step 489/57116: mean batch inertia: 46232.3203125, ewa inertia: 47868.558726099705
# Minibatch step 490/57116: mean batch inertia: 46453.41796875, ewa inertia: 47863.60349052741
# Minibatch step 491/57116: mean batch inertia: 46685.28515625, ewa inertia: 47859.4775087866
# Minibatch step 492/57116: mean batch inertia: 45887.6484375, ewa inertia: 47852.572981794656
# Minibatch step 493/57116: mean batch inertia: 46503.109375, ewa inertia: 47847.847720344034
# Minibatch step 494/57116: mean batch inertia: 45541.73828125, ewa inertia: 47839.77268224846
# Minibatch step 495/57116: mean batch inertia: 46201.421875, ewa inertia: 47834.03585772566
# Minibatch step 496/57116: mean batch inertia: 46342.203125, ewa inertia: 47828.812078686926
# Minibatch step 497/57116: mean batch inertia: 46039.8828125, ewa inertia: 47822.54799089913
# Minibatch step 498/57116: mean batch inertia: 46337.265625, ewa inertia: 47817.34714852626
# Minibatch step 499/57116: mean batch inertia: 46032.21875, ewa inertia: 47811.096369799445
# Minibatch step 500/57116: mean batch inertia: 46657.4375, ewa inertia: 47807.05673526823
# Minibatch step 501/57116: mean batch inertia: 46218.7578125, ewa inertia: 47801.49517167064
# Minibatch step 502/57116: mean batch inertia: 45943.6015625, ewa inertia: 47794.989599377644
# Minibatch step 503/57116: mean batch inertia: 46227.3828125, ewa inertia: 47789.500491051585
# Minibatch step 504/57116: mean batch inertia: 46055.01953125, ewa inertia: 47783.42705863376
# Minibatch step 505/57116: mean batch inertia: 46310.02734375, ewa inertia: 47778.2678243728
# Minibatch step 506/57116: mean batch inertia: 46178.9140625, ewa inertia: 47772.66755131703
# Minibatch step 507/57116: mean batch inertia: 46437.15625, ewa inertia: 47767.99114504923
# Minibatch step 508/57116: mean batch inertia: 46154.375, ewa inertia: 47762.340931047234
# Minibatch step 509/57116: mean batch inertia: 45248.4453125, ewa inertia: 47753.53831199371
# Minibatch step 510/57116: mean batch inertia: 46225.63671875, ewa inertia: 47748.18823477596
# Minibatch step 511/57116: mean batch inertia: 45750.29296875, ewa inertia: 47741.192434788914
# Minibatch step 512/57116: mean batch inertia: 45726.28125, ewa inertia: 47734.137052116894
# ...
# Minibatch step 1058/57116: mean batch inertia: 45671.23046875, ewa inertia: 46352.231925880544
# Minibatch step 1059/57116: mean batch inertia: 46088.390625, ewa inertia: 46351.30806315327
# Minibatch step 1060/57116: mean batch inertia: 45976.8359375, ewa inertia: 46349.99681719542
# Minibatch step 1061/57116: mean batch inertia: 46242.84765625, ewa inertia: 46349.621625306485
# Minibatch step 1062/57116: mean batch inertia: 45910.5859375, ewa inertia: 46348.08430455134
# Minibatch step 1063/57116: mean batch inertia: 46154.86328125, ewa inertia: 46347.40772472491
# Minibatch step 1064/57116: mean batch inertia: 46112.37109375, ewa inertia: 46346.584723996144
# Minibatch step 1065/57116: mean batch inertia: 45755.9453125, ewa inertia: 46344.51654992438
# Minibatch step 1066/57116: mean batch inertia: 46263.72265625, ewa inertia: 46344.23364324257
# Minibatch step 1067/57116: mean batch inertia: 46568.234375, ewa inertia: 46345.01800083277
# Minibatch step 1068/57116: mean batch inertia: 46068.18359375, ewa inertia: 46344.048641640424
# Minibatch step 1069/57116: mean batch inertia: 46738.5859375, ewa inertia: 46345.43014749621
# Minibatch step 1070/57116: mean batch inertia: 45966.43359375, ewa inertia: 46344.10305886906
# Minibatch step 1071/57116: mean batch inertia: 45658.7109375, ewa inertia: 46341.70310013482
# Minibatch step 1072/57116: mean batch inertia: 45827.78515625, ewa inertia: 46339.90357279908
# Minibatch step 1073/57116: mean batch inertia: 46423.64453125, ewa inertia: 46340.19679887855
# Minibatch step 1074/57116: mean batch inertia: 46270.1875, ewa inertia: 46339.95165537152
# Minibatch step 1075/57116: mean batch inertia: 45856.7578125, ewa inertia: 46338.25971108536
# Minibatch step 1076/57116: mean batch inertia: 46079.296875, ewa inertia: 46337.352930716974
# Minibatch step 1077/57116: mean batch inertia: 47001.8984375, ewa inertia: 46339.67989325941
# Minibatch step 1078/57116: mean batch inertia: 45414.9765625, ewa inertia: 46336.441965996986
# Minibatch step 1079/57116: mean batch inertia: 46046.87890625, ewa inertia: 46335.42803634608
# Minibatch step 1080/57116: mean batch inertia: 45781.8046875, ewa inertia: 46333.489477162046
# Minibatch step 1081/57116: mean batch inertia: 45296.28125, ewa inertia: 46329.85760444803
# Minibatch step 1082/57116: mean batch inertia: 46240.265625, ewa inertia: 46329.54389052152
# Minibatch step 1083/57116: mean batch inertia: 45922.59375, ewa inertia: 46328.118920035726
# Minibatch step 1084/57116: mean batch inertia: 47014.51171875, ewa inertia: 46330.52238272669
# Minibatch step 1085/57116: mean batch inertia: 45407.2890625, ewa inertia: 46327.28960283101
# Minibatch step 1086/57116: mean batch inertia: 46591.609375, ewa inertia: 46328.215140966146
# Minibatch step 1087/57116: mean batch inertia: 45738.140625, ewa inertia: 46326.14894492407
# Minibatch step 1088/57116: mean batch inertia: 47251.671875, ewa inertia: 46329.38974208313
# Minibatch step 1089/57116: mean batch inertia: 45701.078125, ewa inertia: 46327.1896555834
# Minibatch step 1090/57116: mean batch inertia: 45839.62890625, ewa inertia: 46325.48242020331
# Minibatch step 1091/57116: mean batch inertia: 46532.68359375, ewa inertia: 46326.20795271338
# Minibatch step 1092/57116: mean batch inertia: 45706.3125, ewa inertia: 46324.03733612812
# Minibatch step 1093/57116: mean batch inertia: 46482.71875, ewa inertia: 46324.59297257814
# Minibatch step 1094/57116: mean batch inertia: 46363.44140625, ewa inertia: 46324.72900366866
# Minibatch step 1095/57116: mean batch inertia: 45509.03125, ewa inertia: 46321.87276869399
# Minibatch step 1096/57116: mean batch inertia: 45891.0390625, ewa inertia: 46320.36416787419
# Minibatch step 1097/57116: mean batch inertia: 46098.4375, ewa inertia: 46319.587072794864
# Minibatch step 1098/57116: mean batch inertia: 46458.1796875, ewa inertia: 46320.072366608125
# Minibatch step 1099/57116: mean batch inertia: 46485.2109375, ewa inertia: 46320.65061334195
# Minibatch step 1100/57116: mean batch inertia: 45576.6953125, ewa inertia: 46318.04559066009
# Minibatch step 1101/57116: mean batch inertia: 46431.62890625, ewa inertia: 46318.44331228807
# Minibatch step 1102/57116: mean batch inertia: 45844.19921875, ewa inertia: 46316.782706309445
# Minibatch step 1103/57116: mean batch inertia: 46566.3203125, ewa inertia: 46317.65648343472
# Minibatch step 1104/57116: mean batch inertia: 45452.92578125, ewa inertia: 46314.62855542568
# Minibatch step 1105/57116: mean batch inertia: 45385.34765625, ewa inertia: 46311.3745994186
# Minibatch step 1106/57116: mean batch inertia: 46636.69140625, ewa inertia: 46312.51372385206
# Minibatch step 1107/57116: mean batch inertia: 45926.71875, ewa inertia: 46311.16282997941
# Minibatch step 1108/57116: mean batch inertia: 45477.6484375, ewa inertia: 46308.244208530494
# Minibatch step 1109/57116: mean batch inertia: 45916.3046875, ewa inertia: 46306.871799003944
# Minibatch step 1110/57116: mean batch inertia: 46008.2265625, ewa inertia: 46305.82606733963
# Minibatch step 1111/57116: mean batch inertia: 45759.37109375, ewa inertia: 46303.91260883049
# Minibatch step 1112/57116: mean batch inertia: 45825.8125, ewa inertia: 46302.23850068677
# Minibatch step 1113/57116: mean batch inertia: 46428.58203125, ewa inertia: 46302.6809032914
# Minibatch step 1114/57116: mean batch inertia: 46505.0859375, ewa inertia: 46303.38964171217
# Minibatch step 1115/57116: mean batch inertia: 46166.0390625, ewa inertia: 46302.90869699169
# Minibatch step 1116/57116: mean batch inertia: 46455.28515625, ewa inertia: 46303.44225610754
# Minibatch step 1117/57116: mean batch inertia: 46538.1640625, ewa inertia: 46304.26415445129
# Minibatch step 1118/57116: mean batch inertia: 46157.72265625, ewa inertia: 46303.75102694723
# Minibatch step 1119/57116: mean batch inertia: 46580.9765625, ewa inertia: 46304.72175570915
# Minibatch step 1120/57116: mean batch inertia: 45595.19921875, ewa inertia: 46302.23730227494
# Minibatch step 1121/57116: mean batch inertia: 45731.578125, ewa inertia: 46300.23909069054
# Minibatch step 1122/57116: mean batch inertia: 46072.09765625, ewa inertia: 46299.44023407816
# Minibatch step 1123/57116: mean batch inertia: 45979.51953125, ewa inertia: 46298.320004561254
# Minibatch step 1124/57116: mean batch inertia: 45053.73828125, ewa inertia: 46293.96199593494
# Minibatch step 1125/57116: mean batch inertia: 46235.3515625, ewa inertia: 46293.75676652355
# Minibatch step 1126/57116: mean batch inertia: 45749.19921875, ewa inertia: 46291.849952012075
# Minibatch step 1127/57116: mean batch inertia: 45585.09375, ewa inertia: 46289.375185134675
# Minibatch step 1128/57116: mean batch inertia: 45878.65625, ewa inertia: 46287.9370178944
# Minibatch step 1129/57116: mean batch inertia: 45793.77734375, ewa inertia: 46286.20667581854
# Minibatch step 1130/57116: mean batch inertia: 46116.375, ewa inertia: 46285.61199577915
# Minibatch step 1131/57116: mean batch inertia: 46537.5625, ewa inertia: 46286.49422187185
# Minibatch step 1132/57116: mean batch inertia: 45304.9765625, ewa inertia: 46283.05735441164
# Minibatch step 1133/57116: mean batch inertia: 45989.48828125, ewa inertia: 46282.02939736447
# Minibatch step 1134/57116: mean batch inertia: 45844.05859375, ewa inertia: 46280.49580539178
# Minibatch step 1135/57116: mean batch inertia: 46217.796875, ewa inertia: 46280.276259761
# Minibatch step 1136/57116: mean batch inertia: 46952.9921875, ewa inertia: 46282.631831726445
# Minibatch step 1137/57116: mean batch inertia: 46315.9921875, ewa inertia: 46282.74864584601
# Minibatch step 1138/57116: mean batch inertia: 46010.1484375, ewa inertia: 46281.79411306021
# Minibatch step 1139/57116: mean batch inertia: 45695.8046875, ewa inertia: 46279.74222130921
# Minibatch step 1140/57116: mean batch inertia: 45464.546875, ewa inertia: 46276.88774555658
# Minibatch step 1141/57116: mean batch inertia: 46348.875, ewa inertia: 46277.13981504304
# Minibatch step 1142/57116: mean batch inertia: 45639.5, ewa inertia: 46274.90706506577
# Minibatch step 1143/57116: mean batch inertia: 45918.9765625, ewa inertia: 46273.66074417619
# Minibatch step 1144/57116: mean batch inertia: 45914.38671875, ewa inertia: 46272.40271565729
# Minibatch step 1145/57116: mean batch inertia: 45973.49609375, ewa inertia: 46271.35606872978
# Minibatch step 1146/57116: mean batch inertia: 45732.609375, ewa inertia: 46269.469601417346
# Minibatch step 1147/57116: mean batch inertia: 46691.9609375, ewa inertia: 46270.94899071955
# Minibatch step 1148/57116: mean batch inertia: 45716.2734375, ewa inertia: 46269.006747152525
# Minibatch step 1149/57116: mean batch inertia: 46469.6171875, ewa inertia: 46269.70920165044
# Minibatch step 1150/57116: mean batch inertia: 45823.6953125, ewa inertia: 46268.14744613052
# Minibatch step 1151/57116: mean batch inertia: 46633.6484375, ewa inertia: 46269.42727889962
# Minibatch step 1152/57116: mean batch inertia: 45370.6484375, ewa inertia: 46266.28012843886
# Minibatch step 1153/57116: mean batch inertia: 46347.84375, ewa inertia: 46266.565730388254
# Minibatch step 1154/57116: mean batch inertia: 45762.171875, ewa inertia: 46264.799552457414
# Minibatch step 1155/57116: mean batch inertia: 45897.48046875, ewa inertia: 46263.513353483555
# Minibatch step 1156/57116: mean batch inertia: 46008.16796875, ewa inertia: 46262.61923992836
# Minibatch step 1157/57116: mean batch inertia: 45652.6953125, ewa inertia: 46260.483539485926
# Minibatch step 1158/57116: mean batch inertia: 45893.578125, ewa inertia: 46259.198789009984
# Minibatch step 1159/57116: mean batch inertia: 46148.8515625, ewa inertia: 46258.81239882281
# Minibatch step 1160/57116: mean batch inertia: 46195.84765625, ewa inertia: 46258.591922428095
# Minibatch step 1161/57116: mean batch inertia: 46353.7421875, ewa inertia: 46258.92509916387
# Minibatch step 1162/57116: mean batch inertia: 45073.8515625, ewa inertia: 46254.77546350808
# Minibatch step 1163/57116: mean batch inertia: 46008.3125, ewa inertia: 46253.912452505334
# Minibatch step 1164/57116: mean batch inertia: 45820.76171875, ewa inertia: 46252.3957384167
# Minibatch step 1165/57116: mean batch inertia: 45466.02734375, ewa inertia: 46249.64220268399
# Minibatch step 1166/57116: mean batch inertia: 45845.234375, ewa inertia: 46248.22613432256
# Minibatch step 1167/57116: mean batch inertia: 46150.9609375, ewa inertia: 46247.8855519736
# Minibatch step 1168/57116: mean batch inertia: 46024.046875, ewa inertia: 46247.101761832
# Minibatch step 1169/57116: mean batch inertia: 46103.3359375, ewa inertia: 46246.59835358578
# Minibatch step 1170/57116: mean batch inertia: 45739.93359375, ewa inertia: 46244.82422389011
# Minibatch step 1171/57116: mean batch inertia: 46286.5546875, ewa inertia: 46244.97034665327
# Minibatch step 1172/57116: mean batch inertia: 45582.01171875, ewa inertia: 46242.64894070203
# Minibatch step 1173/57116: mean batch inertia: 46321.9453125, ewa inertia: 46242.92660368379
# Minibatch step 1174/57116: mean batch inertia: 46013.74609375, ewa inertia: 46242.124108660304
# Minibatch step 1175/57116: mean batch inertia: 46095.13671875, ewa inertia: 46241.60941982855
# Minibatch step 1176/57116: mean batch inertia: 46124.140625, ewa inertia: 46241.198092864965
# Minibatch step 1177/57116: mean batch inertia: 46015.08984375, ewa inertia: 46240.406355623716
# Minibatch step 1178/57116: mean batch inertia: 46022.140625, ewa inertia: 46239.642079627156
# Minibatch step 1179/57116: mean batch inertia: 45592.859375, ewa inertia: 46237.377315045356
# Minibatch step 1180/57116: mean batch inertia: 45968.9609375, ewa inertia: 46236.4374322985
# Minibatch step 1181/57116: mean batch inertia: 45921.1953125, ewa inertia: 46235.333585237495
# Minibatch step 1182/57116: mean batch inertia: 45431.9140625, ewa inertia: 46232.52034353142
# Minibatch step 1183/57116: mean batch inertia: 46273.8125, ewa inertia: 46232.664931524894
# Minibatch step 1184/57116: mean batch inertia: 45956.0234375, ewa inertia: 46231.696247834
# Minibatch step 1185/57116: mean batch inertia: 45659.8984375, ewa inertia: 46229.69404922922
# Minibatch step 1186/57116: mean batch inertia: 46244.9765625, ewa inertia: 46229.74756224763
# Minibatch step 1187/57116: mean batch inertia: 45835.4296875, ewa inertia: 46228.3668247135
# Minibatch step 1188/57116: mean batch inertia: 45864.9609375, ewa inertia: 46227.09432812957
# Minibatch step 1189/57116: mean batch inertia: 45915.6953125, ewa inertia: 46226.00393802427
# Minibatch step 1190/57116: mean batch inertia: 46468.53515625, ewa inertia: 46226.85318168692
# Minibatch step 1191/57116: mean batch inertia: 46043.17578125, ewa inertia: 46226.21001966664
# Minibatch step 1192/57116: mean batch inertia: 45686.25, ewa inertia: 46224.319303790384
# Minibatch step 1193/57116: mean batch inertia: 46168.54296875, ewa inertia: 46224.12399821526
# Minibatch step 1194/57116: mean batch inertia: 45755.07421875, ewa inertia: 46222.4815805686
# Minibatch step 1195/57116: mean batch inertia: 46011.234375, ewa inertia: 46221.741880533715
# Minibatch step 1196/57116: mean batch inertia: 45467.43359375, ewa inertia: 46219.100605992135
# Minibatch step 1197/57116: mean batch inertia: 46773.2734375, ewa inertia: 46221.04108923638
# Minibatch step 1198/57116: mean batch inertia: 45809.40625, ewa inertia: 46219.59971488009
# Minibatch step 1199/57116: mean batch inertia: 46056.55859375, ewa inertia: 46219.02881254477
# Minibatch step 1200/57116: mean batch inertia: 45813.6328125, ewa inertia: 46217.60928401387
# Minibatch step 1201/57116: mean batch inertia: 45625.859375, ewa inertia: 46215.537221440725
# Minibatch step 1202/57116: mean batch inertia: 45258.05078125, ewa inertia: 46212.184501335825
# Minibatch step 1203/57116: mean batch inertia: 46588.8203125, ewa inertia: 46213.50332362229
# Minibatch step 1204/57116: mean batch inertia: 45735.5390625, ewa inertia: 46211.829691160856
# Minibatch step 1205/57116: mean batch inertia: 45794.328125, ewa inertia: 46210.36777396189
# Minibatch step 1206/57116: mean batch inertia: 45793.59765625, ewa inertia: 46208.9084179918
# Minibatch step 1207/57116: mean batch inertia: 46567.30078125, ewa inertia: 46210.163359295715
# Minibatch step 1208/57116: mean batch inertia: 46573.078125, ewa inertia: 46211.43413617596
# Minibatch step 1209/57116: mean batch inertia: 46383.109375, ewa inertia: 46212.03527160781
# Minibatch step 1210/57116: mean batch inertia: 46097.3671875, ewa inertia: 46211.63375157072
# Minibatch step 1211/57116: mean batch inertia: 46043.6328125, ewa inertia: 46211.04548201157
# Minibatch step 1212/57116: mean batch inertia: 45916.97265625, ewa inertia: 46210.01576103188
# Minibatch step 1213/57116: mean batch inertia: 46129.96875, ewa inertia: 46209.73546962308
# Minibatch step 1214/57116: mean batch inertia: 45714.421875, ewa inertia: 46208.00108699664
# Minibatch step 1215/57116: mean batch inertia: 45913.953125, ewa inertia: 46206.97145307954
# Minibatch step 1216/57116: mean batch inertia: 46173.9453125, ewa inertia: 46206.85580924286
# Minibatch step 1217/57116: mean batch inertia: 46072.21484375, ewa inertia: 46206.384352464986
# Minibatch step 1218/57116: mean batch inertia: 46399.8515625, ewa inertia: 46207.061794335175
# Minibatch step 1219/57116: mean batch inertia: 46259.3828125, ewa inertia: 46207.24500082473
# Minibatch step 1220/57116: mean batch inertia: 46326.2265625, ewa inertia: 46207.661624869936
# Minibatch step 1221/57116: mean batch inertia: 46451.81640625, ewa inertia: 46208.51655357689
# Minibatch step 1222/57116: mean batch inertia: 46062.6796875, ewa inertia: 46208.00589340207
# Minibatch step 1223/57116: mean batch inertia: 46049.78515625, ewa inertia: 46207.451870050725
# Minibatch step 1224/57116: mean batch inertia: 46886.8515625, ewa inertia: 46209.83084578607
# Minibatch step 1225/57116: mean batch inertia: 46677.8125, ewa inertia: 46211.46952330143
# Minibatch step 1226/57116: mean batch inertia: 46456.5859375, ewa inertia: 46212.32781924738
# Minibatch step 1227/57116: mean batch inertia: 45932.7734375, ewa inertia: 46211.34893583269
# Converged (lack of improvement in inertia) at step 1227/57116
# Visual vocabulary construction complete.
# Visual vocabulary saved to visual_vocabulary_k400.pkl

# %%
# --- Image Representation (Bag-of-Words Histogram) ---

def compute_bow_histogram(descriptors: Optional[np.ndarray], kmeans_model: MiniBatchKMeans) -> np.ndarray:

    vocab_size = kmeans_model.n_clusters
    histogram = np.zeros(vocab_size, dtype=np.float32)

    if descriptors is not None and descriptors.shape[0] > 0:
        # Find the nearest visual word (cluster center) for each descriptor
        visual_words = kmeans_model.predict(descriptors)

        # Calculate frequencies of visual words
        unique_words, counts = np.unique(visual_words, return_counts=True)
        histogram[unique_words] = counts

        # L2 normalization (optional but recommended)
        # norm = np.linalg.norm(histogram)
        # if norm > 0:
        #     histogram /= norm

    # L1 normalization (another option)
    # total_features = np.sum(histogram)
    # if total_features > 0:
    #     histogram /= total_features

    return histogram


# Computing BoW features for all training data
if vocabulary_kmeans:
    print("\nComputing BoW features for training data...")
    X_train_bow = []
    y_train = []  # List of corresponding labels

    for i in tqdm(range(len(train_paths)), desc="Computing training set BoW"):
        path = train_paths[i]
        label = train_labels[i]

        descriptors = extract_sift_features(path, feature_limit=Config.FEATURE_LIMIT_PER_IMAGE)
        bow_hist = compute_bow_histogram(descriptors, vocabulary_kmeans)

        X_train_bow.append(bow_hist)
        y_train.append(label)  # Keep labels
    X_train_bow = np.array(X_train_bow)
    n_images, n_clusters = X_train_bow.shape
    df = np.count_nonzero(X_train_bow > 0, axis=0)
    doc_freq = df / n_images
    mask = (doc_freq >= 0.001) & (doc_freq <= 0.95)
    hist_filtered = X_train_bow[:, mask]
    from sklearn.feature_extraction.text import TfidfTransformer

    tfidf = TfidfTransformer(norm='l2')
    hist_tfidf = tfidf.fit_transform(hist_filtered).toarray()
    X_train_bow = hist_filtered

    y_train = np.array(y_train)
    print(f"Training set BoW features completed. Feature matrix shape: {X_train_bow.shape}")

    # Computing BoW features for all test data
    X_test_bow_sets = {}
    y_test_sets = {}
    print("\nComputing BoW features for test data...")
    for test_type, (paths, labels) in test_sets.items():
        print(f"Computing test set '{test_type}' BoW features...")
        X_test_bow = []
        y_test = []
        for i in tqdm(range(len(paths)), desc=f"Computing {test_type} BoW"):
            path = paths[i]
            label = labels[i]
            descriptors = extract_sift_features(path, feature_limit=Config.FEATURE_LIMIT_PER_IMAGE)
            bow_hist = compute_bow_histogram(descriptors, vocabulary_kmeans)
            X_test_bow.append(bow_hist)
            y_test.append(label)

        X_test_bow_sets[test_type] = np.array(X_test_bow)
        y_test_sets[test_type] = np.array(y_test)
        print(
            f"Test set '{test_type}' BoW features completed. Feature matrix shape: {X_test_bow_sets[test_type].shape}")

else:
    print("Error: No visual vocabulary available, cannot compute BoW features.")
    X_train_bow, y_train = None, None
    X_test_bow_sets, y_test_sets = {}, {}
# Out:
# Computing BoW features for training data...
# Computing training set BoW: 100%|██████████| 6002/6002 [01:10<00:00, 85.43it/s]
# Training set BoW features completed. Feature matrix shape: (6002, 400)
#
# Computing BoW features for test data...
# Computing test set 'background' BoW features...
# Computing background BoW: 100%|██████████| 100/100 [00:01<00:00, 82.76it/s]
# Test set 'background' BoW features completed. Feature matrix shape: (100, 400)
# Computing test set 'categorization' BoW features...
# Computing categorization BoW: 100%|██████████| 2001/2001 [00:22<00:00, 89.84it/s]
# Test set 'categorization' BoW features completed. Feature matrix shape: (2001, 400)
# Computing test set 'demonstrator' BoW features...
# Computing demonstrator BoW: 100%|██████████| 2001/2001 [00:21<00:00, 94.85it/s]
# Test set 'demonstrator' BoW features completed. Feature matrix shape: (2001, 400)
# Computing test set 'robot' BoW features...
# Computing robot BoW: 100%|██████████| 802/802 [00:14<00:00, 56.70it/s]
# Test set 'robot' BoW features completed. Feature matrix shape: (802, 400)

# %%
# --- Classifier Training and Recognition ---


if X_train_bow is not None and y_train is not None and X_train_bow.shape[0] > 0:
    print("\nStarting classifier training...")

    classifier = SVC(kernel='rbf', C=1.0, probability=False, random_state=Config.RANDOM_STATE)

    classifier.fit(X_train_bow, y_train)
    print("Classifier training completed.")

    classifier_filename = f"bow_classifier_{type(classifier).__name__}_k{Config.VOCAB_SIZE}.pkl"
    with open(classifier_filename, 'wb') as f:
        pickle.dump(classifier, f)
    print(f"Classifier saved to {classifier_filename}")

    print("\nEvaluating model performance on test sets...")
    if not X_test_bow_sets:
        print("No test set BoW features available for evaluation.")
    else:
        for test_type in test_sets.keys():
            print(f"\n--- Evaluating test set: {test_type} ---")
            if test_type not in X_test_bow_sets or X_test_bow_sets[test_type].shape[0] == 0:
                print(f"Skipping evaluation since test set '{test_type}' has no BoW features.")
                continue

            X_test = X_test_bow_sets[test_type]
            X_test_filt = X_test[:, mask]
            X_test_tfidf = tfidf.transform(X_test_filt).toarray()
            y_test = y_test_sets[test_type]

            # Make predictions
            y_pred = classifier.predict(X_test_filt)


            accuracy = accuracy_score(y_test, y_pred)
            print(f"Accuracy: {accuracy:.4f}")


            unique_test_labels = np.unique(y_test)
            current_target_names = [class_names[i] for i in unique_test_labels]

            report = classification_report(y_test, y_pred, labels=unique_test_labels, target_names=current_target_names,
                                           zero_division=0)
            print("Classification Report:")
            print(report)

else:
    print("Error: No training data (BoW features) available, cannot train or evaluate classifier.")



print("\n=== Pipeline Execution Complete ===")
# Out:
# Starting classifier training...
# Classifier training completed.
# Classifier saved to bow_classifier_SVC_k400.pkl
#
# Evaluating model performance on test sets...
#
# --- Evaluating test set: background ---
# Accuracy: 0.9700
# Classification Report:
#               precision    recall  f1-score   support
#
#      bananas       1.00      1.00      1.00        10
#      bottles       1.00      0.70      0.82        10
#        boxes       0.83      1.00      0.91        10
#        bread       1.00      1.00      1.00        10
#         cans       0.91      1.00      0.95        10
#       lemons       1.00      1.00      1.00        10
#        pears       1.00      1.00      1.00        10
#      peppers       1.00      1.00      1.00        10
#     potatoes       1.00      1.00      1.00        10
#       yogurt       1.00      1.00      1.00        10
#
#     accuracy                           0.97       100
#    macro avg       0.97      0.97      0.97       100
# weighted avg       0.97      0.97      0.97       100
#
#
# --- Evaluating test set: categorization ---
# Accuracy: 0.2934
# Classification Report:
#               precision    recall  f1-score   support
#
#      bananas       0.58      0.45      0.51       200
#      bottles       0.13      0.14      0.13       200
#        boxes       0.50      0.31      0.38       200
#        bread       0.11      0.09      0.10       200
#         cans       0.11      0.13      0.12       200
#       lemons       0.40      0.72      0.51       200
#        pears       0.21      0.21      0.21       200
#      peppers       0.32      0.29      0.30       200
#     potatoes       0.31      0.22      0.26       200
#       yogurt       0.34      0.37      0.36       201
#
#     accuracy                           0.29      2001
#    macro avg       0.30      0.29      0.29      2001
# weighted avg       0.30      0.29      0.29      2001
#
#
# --- Evaluating test set: demonstrator ---
# Accuracy: 0.2299
# Classification Report:
#               precision    recall  f1-score   support
#
#      bananas       0.25      0.13      0.17       200
#      bottles       0.31      0.20      0.24       200
#        boxes       0.33      0.64      0.43       200
#        bread       0.20      0.52      0.29       200
#         cans       0.25      0.35      0.29       200
#       lemons       0.42      0.03      0.05       200
#        pears       0.13      0.17      0.15       201
#      peppers       0.27      0.04      0.07       200
#     potatoes       0.11      0.05      0.07       200
#       yogurt       0.19      0.19      0.19       200
#
#     accuracy                           0.23      2001
#    macro avg       0.25      0.23      0.19      2001
# weighted avg       0.25      0.23      0.19      2001
#
#
# --- Evaluating test set: robot ---
# Accuracy: 0.1160
# Classification Report:
#               precision    recall  f1-score   support
#
#      bananas       0.00      0.00      0.00        64
#      bottles       0.17      0.01      0.02        76
#        boxes       0.13      0.96      0.22        76
#        bread       0.67      0.02      0.05        83
#         cans       0.09      0.07      0.08        75
#       lemons       0.00      0.00      0.00        83
#        pears       0.00      0.00      0.00        76
#      peppers       0.00      0.00      0.00        69
#     potatoes       0.00      0.00      0.00        70
#       yogurt       0.38      0.09      0.15       130
#
#     accuracy                           0.12       802
#    macro avg       0.14      0.12      0.05       802
# weighted avg       0.17      0.12      0.06       802
#
#
# === Pipeline Execution Complete ===
